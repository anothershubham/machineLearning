# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Cricket.csv')

# %%
df.head()
# Out:
#                         Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar�(INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 1  KC Sangakkara�(Asia/ICC/SL)  2000-2015  404   380  41  14234   169  41.98
# 2         RT Ponting�(AUS/ICC)  1995-2012  375   365  39  13704   164  42.03
# 3      ST Jayasuriya�(Asia/SL)  1989-2011  445   433  18  13430   189  32.36
# 4   DPMD Jayawardene�(Asia/SL)  1998-2015  448   418  39  12650   144  33.37
#
#       BF     SR  100  50   0
# 0  21367  86.23   49  96  20
# 1  18048  78.86   25  93  15
# 2  17046  80.39   30  82  20
# 3  14725  91.20   28  68  34
# 4  16020  78.96   19  77  28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  79 non-null     object
#  1   Span    79 non-null     object
#  2   Mat     79 non-null     int64
#  3   Inns    79 non-null     int64
#  4   NO      79 non-null     int64
#  5   Runs    79 non-null     int64
#  6   HS      79 non-null     object
#  7   Ave     79 non-null     float64
#  8   BF      79 non-null     int64
#  9   SR      79 non-null     float64
#  10  100     79 non-null     int64
#  11  50      79 non-null     int64
#  12  0       79 non-null     int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 8.1+ KB

# %%
df.describe()
# Out:
#               Mat        Inns         NO          Runs        Ave  \
# count   79.000000   79.000000  79.000000     79.000000  79.000000
# mean   245.075949  230.544304  30.037975   7618.139241  38.523291
# std     74.211716   70.321022  14.421710   2551.873313   5.919093
# min    128.000000  127.000000   4.000000   5080.000000  23.570000
# 25%    188.000000  177.000000  17.500000   5759.000000  34.600000
# 50%    232.000000  217.000000  29.000000   6798.000000  37.870000
# 75%    281.500000  261.500000  40.000000   8739.500000  41.845000
# max    463.000000  452.000000  70.000000  18426.000000  53.940000
#
#                  BF          SR        100         50          0
# count     79.000000   79.000000  79.000000  79.000000  79.000000
# mean    9684.455696   79.295316  11.556962  46.443038  13.253165
# std     3193.835825    9.925307   8.092014  16.351701   5.925755
# min     5504.000000   60.570000   0.000000  23.000000   3.000000
# ...

# %%
df.isnull().sum()
# Out:
# Player    0
# Span      0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Ave       0
# BF        0
# SR        0
# 100       0
# 50        0
# 0         0
# dtype: int64

# %%
df.shape
# Out:
# (79, 13)

# %%
sns.boxplot(df['Mat'])
# Out:
# <AxesSubplot:xlabel='Mat'>

# %%
grouped_df=df[['Mat','Inns','NO','Runs','Ave','SR','100','50','0']]

# %%
grouped_df.head()
# Out:
#    Mat  Inns  NO   Runs    Ave     SR  100  50   0
# 0  463   452  41  18426  44.83  86.23   49  96  20
# 1  404   380  41  14234  41.98  78.86   25  93  15
# 2  375   365  39  13704  42.03  80.39   30  82  20
# 3  445   433  18  13430  32.36  91.20   28  68  34
# 4  448   418  39  12650  33.37  78.96   19  77  28

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()

# %%
scaled = scalar.fit_transform(grouped_df)
scaled.shape
scaled_df = pd.DataFrame(scaled)
# grouped_df.reset_index()
scaled_df.columns = ['Mat','Inns','NO','Runs','Ave','SR','100','50','0']

# %%
scaled_df
# Out:
#          Mat      Inns        NO      Runs       Ave        SR       100  \
# 0   2.955282  3.169333  0.764963  4.262328  1.072294  0.703152  4.656726
# 1   2.155179  2.138915  0.764963  2.609117  0.587725 -0.044139  1.671888
# 2   1.761908  1.924245  0.625397  2.400099  0.596226  0.110997  2.293729
# 3   2.711183  2.897417 -0.840046  2.292041 -1.047909  1.207091  2.044992
# 4   2.751866  2.682747  0.625397  1.984430 -0.876185 -0.034000  0.925678
# ..       ...       ...       ...       ...       ...       ...       ...
# 74 -1.587674 -1.481860 -1.188961 -0.979677  1.106299 -1.457604 -0.069268
# 75 -1.126598 -1.167010  0.067133 -0.984410  0.829159 -0.562275 -1.437319
# 76 -0.651961 -0.709047  0.485831 -0.996241 -0.537836 -0.234765 -0.815478
# 77 -0.638400 -0.995274  0.206699 -0.997819  0.208570  1.332823 -0.691110
# 78  0.270191 -0.036412  1.881490 -1.000973 -1.500174  0.198198 -1.064215
#
#           50         0
# 0   3.050057  1.145837
# 1   2.865418  0.296671
# ...

# %%
from sklearn.neighbors import NearestNeighbors
from random import sample
from numpy.random import uniform
import numpy as np
from math import isnan
 
def hopkins(X):
    d = X.shape[1]
    #d = len(vars) # columns
    n = len(X) # rows
    m = int(0.1 * n) 
    nbrs = NearestNeighbors(n_neighbors=1).fit(X.values)
 
    rand_X = sample(range(0, n, 1), m)
 
    ujd = []
    wjd = []
    for j in range(0, m):
        u_dist, _ = nbrs.kneighbors(uniform(np.amin(X,axis=0),np.amax(X,axis=0),d).reshape(1, -1), 2, return_distance=True)
        ujd.append(u_dist[0][1])
        w_dist, _ = nbrs.kneighbors(X.iloc[rand_X[j]].values.reshape(1, -1), 2, return_distance=True)
        wjd.append(w_dist[0][1])
 
    H = sum(ujd) / (sum(ujd) + sum(wjd))
    if isnan(H):
        print(ujd, wjd)
        H = 0
 
    return H

# %%
#Use the Hopkins Statistic function by passing the above dataframe as a paramter
hopkins(scaled_df)
# Out:
# 0.7496863377697558

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4, max_iter=50,random_state=100)
kmeans.fit(scaled_df)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=50,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=100, tol=0.0001, verbose=0)

# %%
kmeans.labels_
# Out:
# array([1, 1, 1, 1, 1, 1, 1, 1, 1, 2, 2, 2, 2, 0, 2, 0, 2, 2, 2, 0, 2, 2,
#        2, 2, 2, 0, 2, 2, 2, 0, 2, 2, 0, 2, 0, 2, 2, 0, 0, 0, 3, 3, 0, 3,
#        3, 3, 0, 3, 3, 0, 2, 0, 3, 3, 3, 3, 0, 0, 3, 0, 3, 3, 3, 0, 0, 0,
#        3, 3, 0, 3, 0, 3, 3, 3, 0, 0, 3, 0, 3], dtype=int32)

# %%
ssd = []
range_n_clusters = [2, 3, 4, 5, 6, 7, 8]
for num_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=num_clusters, max_iter=50)
    kmeans.fit(scaled_df)
    
    ssd.append(kmeans.inertia_)
    
plt.plot(ssd)

# %%
ssd
# Out:
# [471.39712594975913,
#  397.251345444777,
#  338.1699522809407,
#  298.24844605459674,
#  272.70923815026697,
#  243.0228145927047,
#  223.12152318368226]

# %%
# silhouette analysis

from sklearn.metrics import silhouette_score
range_n_clusters = [2, 3, 4, 5, 6, 7, 8]

for num_clusters in range_n_clusters:
    
    # intialise kmeans
    kmeans = KMeans(n_clusters=num_clusters, max_iter=50)
    kmeans.fit(scaled_df)
    
    cluster_labels = kmeans.labels_
    
    # silhouette score
    silhouette_avg = silhouette_score(scaled_df, cluster_labels)
    print("For n_clusters={0}, the silhouette score is {1}".format(num_clusters, silhouette_avg))
# Out:
# For n_clusters=2, the silhouette score is 0.35630070915878204
# For n_clusters=3, the silhouette score is 0.2527242629448035
# For n_clusters=4, the silhouette score is 0.22390164996619402
# For n_clusters=5, the silhouette score is 0.17958583022286317
# For n_clusters=6, the silhouette score is 0.19329291323481357
# For n_clusters=7, the silhouette score is 0.20007728239297762
# For n_clusters=8, the silhouette score is 0.1945331531605175

# %% [markdown]
# ### In graph we can see, at k=3, the graph which decreasing at a very high rate, starts to drop slowly.
# As well as using Sihouette score we can see that k=2 and k=3 has almost same score.
# So out of common point, we will take k=3 to calculate further

# %%
kmeans = KMeans(n_clusters=4, max_iter=50)
kmeans.fit(scaled_df)
scaled_df['cluster_id'] = kmeans.labels_
scaled_df.head()

# Since we selected 3 clusters, all cluster id will be between 0 and 2
# Out:
#         Mat      Inns        NO      Runs       Ave        SR       100  \
# 0  2.955282  3.169333  0.764963  4.262328  1.072294  0.703152  4.656726
# 1  2.155179  2.138915  0.764963  2.609117  0.587725 -0.044139  1.671888
# 2  1.761908  1.924245  0.625397  2.400099  0.596226  0.110997  2.293729
# 3  2.711183  2.897417 -0.840046  2.292041 -1.047909  1.207091  2.044992
# 4  2.751866  2.682747  0.625397  1.984430 -0.876185 -0.034000  0.925678
#
#          50         0  cluster_id
# 0  3.050057  1.145837           2
# 1  2.865418  0.296671           2
# 2  2.188406  1.145837           2
# 3  1.326755  3.523501           2
# 4  1.880674  2.504502           2

# %%
sns.boxplot(x='cluster_id', y='Mat', data=scaled_df)
# Out:
# <AxesSubplot:xlabel='cluster_id', ylabel='Mat'>

# %%
sns.boxplot(x='cluster_id', y='Inns', data=scaled_df)
# Out:
# <AxesSubplot:xlabel='cluster_id', ylabel='Inns'>

# %%
scaled_df.shape
# Out:
# (79, 10)

# %%
scaled_df['Player'] = df['Player']

# %%
scaled_df[scaled_df['cluster_id']==0]
# Out:
#          Mat      Inns        NO      Runs       Ave        SR       100  \
# 25 -0.774011 -0.723358 -0.072433  0.208174  2.621216  1.185798  1.920624
# 32 -0.163763 -0.179526  0.764963 -0.093521  0.540118 -1.245686 -0.442373
# 34 -1.207965 -1.109765 -1.398310 -0.170424  1.993826  0.989089  1.671888
# 37 -0.651961 -0.522999 -1.398310 -0.248116 -0.092373  0.153583 -0.193637
# 39 -0.814694 -0.651801 -0.770263 -0.323441  0.412600 -0.735663  0.179468
# 40 -0.434984 -0.322640 -0.979612 -0.328173 -0.541237 -0.477102 -0.939846
# 42 -0.787572 -0.909406 -0.421348 -0.353807  1.441247  1.105695 -0.069268
# 46 -0.746888 -0.780603 -0.072433 -0.446485  0.951577  0.277287  0.676941
# 47 -0.285812 -0.193837 -0.002650 -0.540346 -0.869384 -1.577252 -0.815478
# 48 -0.557034 -0.537310 -1.119178 -0.582938 -0.718062 -0.432487  0.303836
# 49 -1.140159 -1.081142 -1.049395 -0.585699  0.897169 -0.034000 -0.193637
# 51 -1.099476 -0.995274 -0.351565 -0.611333  1.034889 -0.682936 -0.566742
# ...

# %%
scaled_df[scaled_df['Player']=='V Kohli�(INDIA)']
# Out:
#          Mat      Inns        NO      Runs       Ave        SR       100  \
# 25 -0.774011 -0.723358 -0.072433  0.208174  2.621216  1.185798  1.920624
#
#           50         0  cluster_id           Player
# 25 -0.211907 -0.382662           0  V Kohli�(INDIA)

# %%
scaled_df['cluster_id'].value_counts()
# Out:
# 0    36
# 3    23
# 1    15
# 2     5
# Name: cluster_id, dtype: int64
