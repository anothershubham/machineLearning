# %%
# Importing the required libraries
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline

# %%
# Reading the csv file and putting it into 'df' object.
df = pd.read_csv('heart_v2.csv')

# %%
df.columns
# Out:
# Index(['age', 'sex', 'BP', 'cholestrol', 'heart disease'], dtype='object')

# %%
df.head()
# Out:
#    age  sex   BP  cholestrol  heart disease
# 0   70    1  130         322              1
# 1   67    0  115         564              0
# 2   57    1  124         261              1
# 3   64    1  128         263              0
# 4   74    0  120         269              0

# %%
# Putting feature variable to X
X = df.drop('heart disease',axis=1)

# Putting response variable to y
y = df['heart disease']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((189, 4), (81, 4))

# %% [markdown]
# Fitting the decision tree with default hyperparameters, apart from max_depth which is 3 so that we can plot and read the tree.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(max_depth=3)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
# !pip install six
# !pip install pydotplus
# !pip install graphviz
# Out:
# Requirement already satisfied: six in /Users/aletheadevelopmentteam/miniconda3/envs/env/lib/python3.6/site-packages (1.15.0)
# Requirement already satisfied: pydotplus in /Users/aletheadevelopmentteam/miniconda3/envs/env/lib/python3.6/site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in /Users/aletheadevelopmentteam/miniconda3/envs/env/lib/python3.6/site-packages (from pydotplus) (2.4.7)
# Requirement already satisfied: graphviz in /Users/aletheadevelopmentteam/miniconda3/envs/env/lib/python3.6/site-packages (0.16)

# %%
# !conda install six --yes
# !conda install pydotplus --yes
# !conda install graphviz --yes
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/aletheadevelopmentteam/miniconda3/envs/env
#
#   added / updated specs:
#     - six
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2021.1.19  |       hecd8cb5_0         121 KB
#     openssl-1.1.1j             |       h9ed2024_0         2.2 MB
#     six-1.15.0                 |   py36hecd8cb5_0          27 KB
#     ------------------------------------------------------------
#                                            Total:         2.4 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2020.12.8-hecd8cb5_0 --> 2021.1.19-hecd8cb5_0
#   openssl                                 1.1.1i-h9ed2024_0 --> 1.1.1j-h9ed2024_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   six                conda-forge/noarch::six-1.15.0-pyh9f0~ --> pkgs/main/osx-64::six-1.15.0-py36hecd8cb5_0
#
#
#
# Downloading and Extracting Packages
# openssl-1.1.1j       | 2.2 MB    | ##################################### | 100%
# six-1.15.0           | 27 KB     | ##################################### | 100%
# ca-certificates-2021 | 121 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/aletheadevelopmentteam/miniconda3/envs/env
#
#   added / updated specs:
#     - pydotplus
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pydotplus-2.0.2            |           py36_1          42 KB
#     ------------------------------------------------------------
#                                            Total:          42 KB
#
# The following NEW packages will be INSTALLED:
#
#   pydotplus          pkgs/main/osx-64::pydotplus-2.0.2-py36_1
#
#
#
# Downloading and Extracting Packages
# pydotplus-2.0.2      | 42 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/aletheadevelopmentteam/miniconda3/envs/env
#
#   added / updated specs:
#     - graphviz
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cairo-1.14.12              |       hc4e6be7_4         860 KB
#     fontconfig-2.13.1          |       ha9ee91d_0         211 KB
#     fribidi-1.0.10             |       haf1e3a3_0          63 KB
#     gettext-0.19.8.1           |       h15daf44_3         2.6 MB
#     glib-2.63.1                |       hd977a24_0         2.6 MB
#     graphite2-1.3.14           |       h38d11af_0          80 KB
#     graphviz-2.40.1            |       hefbbd9a_2         6.3 MB
#     harfbuzz-1.8.8             |       hb8d4a28_0         414 KB
#     libffi-3.2.1               |    h0a44026_1007          43 KB
#     pango-1.42.4               |       h7e27002_1         456 KB
#     pixman-0.40.0              |       haf1e3a3_0         340 KB
#     python-3.6.10              |       hc70fcce_1        17.1 MB
#     ------------------------------------------------------------
#                                            Total:        31.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   cairo              pkgs/main/osx-64::cairo-1.14.12-hc4e6be7_4
#   expat              pkgs/main/osx-64::expat-2.2.10-hb1e8313_2
#   fontconfig         pkgs/main/osx-64::fontconfig-2.13.1-ha9ee91d_0
#   fribidi            pkgs/main/osx-64::fribidi-1.0.10-haf1e3a3_0
#   gettext            pkgs/main/osx-64::gettext-0.19.8.1-h15daf44_3
#   glib               pkgs/main/osx-64::glib-2.63.1-hd977a24_0
#   graphite2          pkgs/main/osx-64::graphite2-1.3.14-h38d11af_0
#   graphviz           pkgs/main/osx-64::graphviz-2.40.1-hefbbd9a_2
#   harfbuzz           pkgs/main/osx-64::harfbuzz-1.8.8-hb8d4a28_0
#   icu                pkgs/main/osx-64::icu-58.2-h0a44026_3
#   libiconv           pkgs/main/osx-64::libiconv-1.16-h1de35cc_0
#   libxml2            pkgs/main/osx-64::libxml2-2.9.10-h7cdb67c_3
#   pango              pkgs/main/osx-64::pango-1.42.4-h7e27002_1
#   pcre               pkgs/main/osx-64::pcre-8.44-hb1e8313_0
#   pixman             pkgs/main/osx-64::pixman-0.40.0-haf1e3a3_0
#
# The following packages will be DOWNGRADED:
#
#   libffi                                     3.3-hb1e8313_2 --> 3.2.1-h0a44026_1007
#   python                                  3.6.12-h26836e1_2 --> 3.6.10-hc70fcce_1
#
#
#
# Downloading and Extracting Packages
# glib-2.63.1          | 2.6 MB    | ##################################### | 100%
# harfbuzz-1.8.8       | 414 KB    | ##################################### | 100%
# fribidi-1.0.10       | 63 KB     | ##################################### | 100%
# gettext-0.19.8.1     | 2.6 MB    | ##################################### | 100%
# fontconfig-2.13.1    | 211 KB    | ##################################### | 100%
# graphite2-1.3.14     | 80 KB     | ##################################### | 100%
# graphviz-2.40.1      | 6.3 MB    | ##################################### | 100%
# pango-1.42.4         | 456 KB    | ##################################### | 100%
# pixman-0.40.0        | 340 KB    | ##################################### | 100%
# cairo-1.14.12        | 860 KB    | ##################################### | 100%
# python-3.6.10        | 17.1 MB   | ##################################### | 100%
# libffi-3.2.1         | 43 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# Importing required packages for visualization
from IPython.display import Image  
from six import StringIO
from sklearn.tree import export_graphviz
import pydotplus, graphviz

# %%
import os

os.environ['PATH'] = os.environ['PATH']+';'+os.environ['CONDA_PREFIX']+r"\Library\bin\graphviz"

# %%
# plotting tree with max_depth=3
dot_data = StringIO()  

export_graphviz(dt, out_file=dot_data, filled=True, rounded=True,
                feature_names=X.columns, 
                class_names=['No Disease', "Disease"])

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
#Image(graph.create_png(),width=800,height=900)
# graph.write_pdf("dt_heartdisease.pdf")

# %% [markdown]
# #### Evaluating model performance

# %%
y_train_pred = dt.predict(X_train)
y_test_pred = dt.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
print(accuracy_score(y_train, y_train_pred))
confusion_matrix(y_train, y_train_pred)
# Out:
# 0.7407407407407407
# array([[82, 19],
#        [30, 58]])

# %%
print(accuracy_score(y_test, y_test_pred))
confusion_matrix(y_test, y_test_pred)
# Out:
# 0.6049382716049383
# array([[35, 14],
#        [18, 14]])
