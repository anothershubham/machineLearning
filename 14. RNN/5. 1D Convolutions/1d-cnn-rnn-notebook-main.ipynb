# %% [markdown]
# # Predicting the Dow Jones with News

# %% [markdown]
# ## General Data flow for a Text Related Business Problem

# %% [markdown]
# ![title](resources/textmining.png)

# %% [markdown]
# # Problem Statement & Reference Architecture
#
# * **Aim**: Use Reddit News Headlines to predict the movement of Dow Jones Industrial Average.
#
#
# * **Data Source**: https://www.kaggle.com/aaron7sun/stocknews
#
#
# * **Data Description**: Dow Jones details on Open, High, Low and Close for each day from 2008-08-08 to 2016-07-01 and headlines for those dates from Reddit News.
#
#
# * **Methodology**: For this project, we will use GloVe to create our word embeddings and CNNs followed by LSTMs to build our model. This model is based off the work done in this paper https://www.aclweb.org/anthology/C/C16/C16-1229.pdf.

# %% [markdown]
# ![basic](resources/basic_intent.png)

# %% [markdown]
# # Installation Prerequisites

# %%
# !apt-get update  && apt-get install -y --allow-downgrades --no-install-recommends git wget

# %%
# !pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.17-py3-none-any.whl (18 kB)
# Installing collected packages: graphviz
# Successfully installed graphviz-0.17

# %%
# !pip install nltk keras
# Out:
# Requirement already satisfied: nltk in /Users/alethea/miniconda3/lib/python3.7/site-packages (3.5)
# Requirement already satisfied: keras in /Users/alethea/miniconda3/lib/python3.7/site-packages (2.3.1)
# Requirement already satisfied: regex in /Users/alethea/miniconda3/lib/python3.7/site-packages (from nltk) (2018.7.11)
# Requirement already satisfied: tqdm in /Users/alethea/miniconda3/lib/python3.7/site-packages (from nltk) (4.59.0)
# Requirement already satisfied: click in /Users/alethea/miniconda3/lib/python3.7/site-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in /Users/alethea/miniconda3/lib/python3.7/site-packages (from nltk) (1.0.1)
# Requirement already satisfied: scipy>=0.14 in /Users/alethea/miniconda3/lib/python3.7/site-packages (from keras) (1.6.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /Users/alethea/miniconda3/lib/python3.7/site-packages (from keras) (1.1.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /Users/alethea/miniconda3/lib/python3.7/site-packages (from keras) (1.0.8)
# Requirement already satisfied: six>=1.9.0 in /Users/alethea/miniconda3/lib/python3.7/site-packages (from keras) (1.16.0)
# Requirement already satisfied: h5py in /Users/alethea/miniconda3/lib/python3.7/site-packages (from keras) (2.8.0)
# Requirement already satisfied: numpy>=1.9.1 in /Users/alethea/miniconda3/lib/python3.7/site-packages (from keras) (1.20.2)
# Requirement already satisfied: pyyaml in /Users/alethea/miniconda3/lib/python3.7/site-packages (from keras) (5.4.1)

# %%
# !pip install pydot
# Out:
# Collecting pydot
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: pyparsing>=2.1.4 in /Users/alethea/miniconda3/lib/python3.7/site-packages (from pydot) (2.4.7)
# Installing collected packages: pydot
# Successfully installed pydot-1.4.2

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /Users/alethea/miniconda3/lib/python3.7/site-packages (0.17)

# %%
# !brew install wget
# Out:
# Updating Homebrew...
# ==> Downloading https://ghcr.io/v2/homebrew/core/wget/manifests/1.21.1-1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/wget/blobs/sha256:277577a3a30ff
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Pouring wget--1.21.1.big_sur.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/wget/1.21.1: 88 files, 4MB

# %%
# !wget http://nlp.stanford.edu/data/glove.840B.300d.zip
# Out:
# --2021-07-18 16:42:27--  http://nlp.stanford.edu/data/glove.840B.300d.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.840B.300d.zip [following]
# --2021-07-18 16:42:28--  https://nlp.stanford.edu/data/glove.840B.300d.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.840B.300d.zip [following]
# --2021-07-18 16:42:29--  http://downloads.cs.stanford.edu/nlp/data/glove.840B.300d.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2176768927 (2.0G) [application/zip]
# Saving to: ‘glove.840B.300d.zip’
#
# glove.840B.300d.zip  16%[==>                 ] 349.15M   458KB/s    eta 19m 31s^C

# %%
# !unzip glove.840B.300d.zip
# !unzip glove.6B.zip
# Out:
# Archive:  glove.6B.zip
#   inflating: glove.6B.50d.txt
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import re
import nltk
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.metrics import median_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/alethea/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Keras Imports
from tensorflow.keras import Sequential, Model
from tensorflow.keras import initializers
from tensorflow.keras.layers import Dropout, Activation, Embedding, Convolution1D, MaxPooling1D, Input, Dense, add, BatchNormalization, Flatten, Reshape, Concatenate, LSTM, GRU
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras import regularizers
from tensorflow.keras.utils import plot_model
import re

# %%
dj = pd.read_csv("dowjones-news-data/DowJones.csv")
news = pd.read_csv("dowjones-news-data/News.csv")

# %% [markdown]
# ## Inspect the data

# %%
dj.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2016-07-01  17924.240234  18002.380859  17916.910156  17949.369141
# 1  2016-06-30  17712.759766  17930.609375  17711.800781  17929.990234
# 2  2016-06-29  17456.019531  17704.509766  17456.019531  17694.679688
# 3  2016-06-28  17190.509766  17409.720703  17190.509766  17409.720703
# 4  2016-06-27  17355.210938  17355.210938  17063.080078  17140.240234
#
#       Volume     Adj Close
# 0   82160000  17949.369141
# 1  133030000  17929.990234
# 2  106380000  17694.679688
# 3  112190000  17409.720703
# 4  138740000  17140.240234

# %%
dj.isnull().sum() #No missing data
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
news.isnull().sum() #No missing data
# Out:
# Date    0
# News    0
# dtype: int64

# %%
news.head()
# Out:
#          Date                                               News
# 0  2016-07-01  A 117-year-old woman in Mexico City finally re...
# 1  2016-07-01   IMF chief backs Athens as permanent Olympic host
# 2  2016-07-01  The president of France says if Brexit won, so...
# 3  2016-07-01  British Man Who Must Give Police 24 Hours' Not...
# 4  2016-07-01  100+ Nobel laureates urge Greenpeace to stop o...

# %%
print(dj.shape)
print(news.shape)
# Out:
# (1989, 7)
# (73608, 2)

# %%
# Compare the number of unique dates. We want matching values.
print(len(set(dj.Date)))
print(len(set(news.Date)))
# Out:
# 1989
# 2943

# %%
# Remove the extra dates that are in news
news = news[news.Date.isin(dj.Date)]

# %%
print(len(set(dj.Date)))
print(len(set(news.Date)))
# Out:
# 1989
# 1989

# %%
# Remove unwanted features - keep the 'Open' price only
dj = dj.drop(['High','Low','Close','Volume','Adj Close'], 1)
dj.head()
# Out:
#          Date          Open
# 0  2016-07-01  17924.240234
# 1  2016-06-30  17712.759766
# 2  2016-06-29  17456.019531
# 3  2016-06-28  17190.509766
# 4  2016-06-27  17355.210938

# %%
# Calculate the difference in opening prices between the following and current day.
# The model will try to predict the change in Open value based on the today's news.
dj = dj.set_index('Date')
dj.head()
# Out:
#                     Open
# Date
# 2016-07-01  17924.240234
# 2016-06-30  17712.759766
# 2016-06-29  17456.019531
# 2016-06-28  17190.509766
# 2016-06-27  17355.210938

# %%
# Target variable = Tomorrow's Open Price - Today's Open Price
dj = -1 * dj.diff(periods=1)

# %%
dj.head()
# Out:
#                   Open
# Date
# 2016-07-01         NaN
# 2016-06-30  211.480468
# 2016-06-29  256.740235
# 2016-06-28  265.509765
# 2016-06-27 -164.701172

# %%
dj['Date'] = dj.index
dj = dj.reset_index(drop=True)

# %%
dj.head()
# Out:
#          Open        Date
# 0         NaN  2016-07-01
# 1  211.480468  2016-06-30
# 2  256.740235  2016-06-29
# 3  265.509765  2016-06-28
# 4 -164.701172  2016-06-27

# %%
# Remove top row since it has a null value.
dj = dj[dj.Open.notnull()]

# %%
# Check if there are any more null values.
dj.isnull().sum()
# Out:
# Open    0
# Date    0
# dtype: int64

# %% [markdown]
# ## Combine the two datasets - For each date, get all the headlines and the price

# %%
# Create a list of the opening prices and their corresponding daily headlines from the news
# Define/Initialize the variables
price = []
headlines = []

# For all the rows in the dataframe
for row in dj.iterrows():
    # define a new variable to store all the headlines for the day
    daily_headlines = []
    # Spot the date in the given row
    date = row[1]['Date']
    # Store the price for the date
    price.append(row[1]['Open'])
    for row_ in news[news.Date==date].iterrows():
        daily_headlines.append(row_[1]['News'])

    # Append the headlines for the date
    headlines.append(daily_headlines)
    # Track progress
    if len(price) % 500 == 0:
        print(len(price))
# Out:
# 500
# 1000
# 1500

# %% [markdown]
# <table size="100">
#     <tr>
#         <td>headlines</td>
#         <td>price</td>
#     </tr>
#     <tr>
#         <td>headline-1, headline-2 ..., headline-n</td>
#         <td>211.48</td>
#     </tr>
# </table>

# %%
# Check how headlines look like
headlines[:1], price[:1]
# Out:
# ([['Jamaica proposes marijuana dispensers for tourists at airports following legalisation: The kiosks and desks would give people a license to purchase up to 2 ounces of the drug to use during their stay',
#    "Stephen Hawking says pollution and 'stupidity' still biggest threats to mankind: we have certainly not become less greedy or less stupid in our treatment of the environment over the past decade",
#    'Boris Johnson says he will not run for Tory party leadership',
#    'Six gay men in Ivory Coast were abused and forced to flee their homes after they were pictured signing a condolence book for victims of the recent attack on a gay nightclub in Florida',
#    'Switzerland denies citizenship to Muslim immigrant girls who refused to swim with boys: report',
#    'Palestinian terrorist stabs israeli teen girl to death in her bedroom',
#    'Puerto Rico will default on $1 billion of debt on Friday',
#    'Republic of Ireland fans to be awarded medal for sportsmanship by Paris mayor.',
#    "Afghan suicide bomber 'kills up to 40' - BBC News",
#    'US airstrikes kill at least 250 ISIS fighters in convoy outside Fallujah, official says',
#    'Turkish Cop Who Took Down Istanbul Gunman Hailed a Hero',
#    "Cannabis compounds could treat Alzheimer's by removing plaque-forming proteins from brain cells, research suggests",
#    "Japan's top court has approved blanket surveillance of the country's Muslims: 'They made us terrorist suspects, we never did anything wrong,' says Japanese Muslim, Mohammed Fujita",
#    'CIA Gave Romania Millions to Host Secret Prisons',
#    'Groups urge U.N. to suspend Saudi Arabia from rights council',
#    'Googles free wifi at Indian railway stations is better than most of the countrys paid services',
#    "Mounting evidence suggests 'hobbits' were wiped out by modern humans' ancestors 50,000 years ago.",
#    "The men who carried out Tuesday's terror attack at Istanbul's Ataturk Airport were from Russia, Uzbekistan and Kyrgyzstan, a Turkish offical said.",
#    'Calls to suspend Saudi Arabia from UN Human Rights Council because of military aggresion in Yemen',
#    'More Than 100 Nobel Laureates Call Out Greenpeace For Anti-GMO Obstruction In Developing World',
#    'British pedophile sentenced to 85 years in US for trafficking child abuse images: Domminich Shaw, a kingpin of sexual violence against children, sent dozens of images online and discussed plans to assault and kill a child while on probation',
#    'US permitted 1,200 offshore fracks in Gulf of Mexico between 2010 and 2014 and allowed 72 billion gallons of chemical discharge in 2014.',
#    'We will be swimming in ridicule - French beach police to carry guns while in swimming trunks: Police lifeguards on Frances busiest beaches will carry guns and bullet-proof vests for the first time this summer amid fears that terrorists could target holidaymakers.',
#    "UEFA says no minutes of silence for Istanbul victims at Euro 2016 because 'Turkey have already been eliminated'",
#    'Law Enforcement Sources: Gun Used in Paris Terrorist Attacks Came from Phoenix']],
#  [211.48046800000157])

# %% [markdown]
# ## Clean up the price list

# %%
price[:2]
# Out:
# [211.48046800000157, 256.7402349999975]

# %%
# Normalize opening prices (target values)
max_price = max(price)
min_price = min(price)
mean_price = np.mean(price)
def normalize(price):
    return ((price-min_price)/(max_price-min_price))

# %%
norm_price = []
for p in price:
    norm_price.append(normalize(p))

# %%
# Check that normalization worked well
print(min(norm_price))
print(max(norm_price))
print(np.mean(norm_price))
# Out:
# 0.0
# 1.0
# 0.4551577545098642

# %%
# Compare the number of headlines for each day
print(max(len(i) for i in headlines))
print(min(len(i) for i in headlines))
print(np.mean([len(i) for i in headlines]))
# Out:
# 25
# 22
# 24.996478873239436

# %%
norm_price[:2]
# Out:
# [0.5780280759194737, 0.6047364662478155]

# %% [markdown]
# ## Clean up the headlines list

# %%
# remove contractions
def decontracted(phrase):
    if "'" in phrase:
        # specific
        phrase = re.sub(r"won't", "will not", phrase)
        phrase = re.sub(r"can\'t", "can not", phrase)

        # general
        phrase = re.sub(r"n\'t", " not", phrase)
        phrase = re.sub(r"\'re", " are", phrase)
        phrase = re.sub(r"\'s", " is", phrase)
        phrase = re.sub(r"\'d", " would", phrase)
        phrase = re.sub(r"\'ll", " will", phrase)
        phrase = re.sub(r"\'t", " not", phrase)
        phrase = re.sub(r"\'ve", " have", phrase)
        phrase = re.sub(r"\'m", " am", phrase)
    return phrase

text = "I should've gone to dentist so my teeth wouldn't hurt"
text1 = "But I am good now"
print(decontracted(text))
print(decontracted(text1))
# Out:
# I should have gone to dentist so my teeth would not hurt
# But I am good now

# %%
def clean_text(text):
    '''Remove unwanted characters and format the text to create fewer nulls word embeddings'''
    
    # Convert words to lower case
    text = text.lower()
    
    # Replace contractions with their longer forms 
    if True:
        text = text.split()
        new_text = []
        # Remove the contractions
        for word in text:
            new_text.append(decontracted(word))
        # Recreate the sentence
        text = " ".join(new_text)
    
    # Format words and remove unwanted characters
    text = re.sub(r'&amp;', '', text) 
    text = re.sub(r'0,0', '00', text) 
    text = re.sub(r'[_"\-;%()|.,+&=*%.,!?:#@\[\]]', ' ', text)
    text = re.sub(r'\'', ' ', text)
    text = re.sub(r'\$', ' $ ', text)
    text = re.sub(r'u s ', ' united states ', text)
    text = re.sub(r'u n ', ' united nations ', text)
    text = re.sub(r'u k ', ' united kingdom ', text)
    text = re.sub(r'j k ', ' jk ', text)
    text = re.sub(r' s ', ' ', text)
    text = re.sub(r' yr ', ' year ', text)
    text = re.sub(r' l g b t ', ' lgbt ', text)
    text = re.sub(r'0km ', '0 km ', text)
    
    # Remove stop words
    text = text.split()
    stops = set(stopwords.words("english"))
    text = [w for w in text if not w in stops]
    text = " ".join(text)

    return text

# %%
# Clean the headlines
clean_headlines = []

for daily_headlines in headlines:
    clean_daily_headlines = []
    for headline in daily_headlines:
        clean_daily_headlines.append(clean_text(headline))
    clean_headlines.append(clean_daily_headlines)

# %%
# Take a look at some headlines to ensure everything was cleaned well
clean_headlines[:2]
# Out:
# [['jamaica proposes marijuana dispensers tourists airports following legalisation kiosks desks would give people license purchase 2 ounces drug use stay',
#   'stephen hawking says pollution istupidity still biggest threats mankind certainly become less greedy less stupid treatment environment past decade',
#   'boris johnson says run tory party leadership',
#   'six gay men ivory coast abused forced flee homes pictured signing condolence book victims recent attack gay nightclub florida',
#   'switzerland denies citizenship muslim immigrant girls refused swim boys report',
#   'palestinian terrorist stabs israeli teen girl death bedroom',
#   'puerto rico default $ 1 billion debt friday',
#   'republic ireland fans awarded medal sportsmanship paris mayor',
#   'afghan suicide bomber kills 40 bbc news',
#   'us airstrikes kill least 250 isis fighters convoy outside fallujah official says',
#   'turkish cop took istanbul gunman hailed hero',
#   'cannabis compounds could treat alzheimer removing plaque forming proteins brain cells research suggests',
#   'japan top court approved blanket surveillance country muslims nothey made us terrorist suspects never anything wrong says japanese muslim mohammed fujita',
#   'cia gave romania millions host secret prisons',
#   'groups urge united nations suspend saudi arabia rights council',
#   'googles free wifi indian railway stations better countrys paid services',
#   'mounting evidence suggests hobbits wiped modern humans ancestors 50000 years ago',
#   'men carried tuesday terror attack istanbul ataturk airport russia uzbekistan kyrgyzstan turkish offical said',
#   'calls suspend saudi arabia un human rights council military aggresion yemen',
#   '100 nobel laureates call greenpeace anti gmo obstruction developing world',
#   'british pedophile sentenced 85 years us trafficking child abuse images domminich shaw kingpin sexual violence children sent dozens images online discussed plans assault kill child probation',
#   'us permitted 1 200 offshore fracks gulf mexico 2010 2014 allowed 72 billion gallons chemical discharge 2014',
#   'swimming ridicule french beach police carry guns swimming trunks police lifeguards frances busiest beaches carry guns bullet proof vests first time summer amid fears terrorists could target holidaymakers',
#   'uefa says minutes silence istanbul victims euro 2016 noturkey already eliminated',
#   'law enforcement sources gun used paris terrorist attacks came phoenix'],
#  ['explosion airport istanbul',
#   'yemeni former president terrorism offspring wahhabism al saud regime',
#   'uk must accept freedom movement access eu market',
#   'devastated scientists late captive breed mammal lost climate change australian conservationists spent 5 months obtaining permissions planning captive breeding program arrived rodents tiny island late',
#   'british labor party leader jeremy corbyn loses confidence vote refuses resign',
#   'muslim shop uk firebombed people inside',
#   'mexican authorities sexually torture women prison',
#   'uk shares pound continue recover',
#   'iceland historian johannesson wins presidential election',
#   '99 million year old bird wings found encased amber finding things trapped amber far rare researchers burma found pair tiny bird like wings frozen inside knew something special',
#   'chatbot programmed british teenager successfully challenged 160000 parking tickets since launch last year',
#   'philippine president elect said monday would aggressively promote artificial birth control country even risk getting fight dominant catholic church staunchly opposes use contraceptives',
#   'former belgian prime minister ridicules nigel farage accuses ukip leader lying eu referendum campaign',
#   'brexiteer nigel farage eu laughing',
#   'islamic state bombings southern yemen kill 38 people',
#   'escape tunnel dug hand found holocaust massacre site',
#   'land beijing sinking much four inches per year overconsumption groundwater according new research',
#   'car bomb anti islamic attack mosque perth australia',
#   'emaciated lions taiz zoo trapped blood soaked cages left starve months due yemeni civil war',
#   'rupert murdoch describes brexit wonderful media mogul likened leaving eu prison break shared view donald trump able man',
#   '40 killed yemen suicide attacks',
#   'google found disastrous symantec norton vulnerabilities bad gets',
#   'extremist violence rise germany domestic intelligence agency says far right far left islamist radical groups gaining membership country',
#   'bbc news labour mps pass corbyn confidence motion',
#   'tiny new zealand town notoo many jobs launches drive recruit outsiders']]

# %%
print('Roughly the number of unique words in English: {}'.format(len({word: None 
                                                                      for headlines in clean_headlines 
                                                                      for headline in headlines 
                                                                      for word in headline.split()})))
# Out:
# Roughly the number of unique words in English: 36311

# %%
# Create the word vocab
import collections
words = [word for headlines in clean_headlines for headline in headlines for word in headline.split()]
word_counts = collections.Counter(words)

# %%
word_counts
# Out:
# Counter({'jamaica': 23,
#          'proposes': 65,
#          'marijuana': 216,
#          'dispensers': 1,
#          'tourists': 95,
#          'airports': 33,
#          'following': 219,
#          'legalisation': 4,
#          'kiosks': 2,
#          'desks': 1,
#          'would': 888,
#          'give': 289,
#          'people': 1887,
#          'license': 21,
#          'purchase': 26,
#          '2': 733,
#          'ounces': 2,
#          'drug': 648,
#          'use': 605,
#          'stay': 107,
#          'stephen': 59,
#          'hawking': 23,
#          'says': 2563,
#          'pollution': 135,
#          'istupidity': 2,
#          'still': 326,
#          'biggest': 331,
#          'threats': 118,
#          'mankind': 13,
#          'certainly': 12,
#          'become': 314,
#          'less': 204,
#          'greedy': 6,
#          'stupid': 27,
#          'treatment': 133,
#          'environment': 96,
#          'past': 242,
#          'decade': 109,
#          'boris': 23,
#          'johnson': 24,
#          'run': 291,
#          'tory': 24,
#          'party': 512,
#          'leadership': 54,
#          'six': 295,
#          'gay': 444,
#          'men': 520,
#          'ivory': 106,
#          'coast': 209,
#          'abused': 54,
#          'forced': 334,
#          'flee': 91,
#          'homes': 199,
#          'pictured': 4,
#          'signing': 23,
#          'condolence': 2,
#          'book': 90,
#          'victims': 240,
#          'recent': 177,
#          'attack': 951,
#          'nightclub': 11,
#          'florida': 11,
#          'switzerland': 111,
#          'denies': 113,
#          'citizenship': 77,
#          'muslim': 504,
#          'immigrant': 28,
#          'girls': 230,
#          'refused': 96,
#          'swim': 18,
#          'boys': 94,
#          'report': 869,
#          'palestinian': 638,
#          'terrorist': 242,
#          'stabs': 9,
#          'israeli': 1322,
#          'teen': 65,
#          'girl': 361,
#          'death': 953,
#          'bedroom': 4,
#          'puerto': 19,
#          'rico': 17,
#          'default': 32,
#          '$': 1569,
#          '1': 935,
#          'billion': 597,
#          'debt': 192,
#          'friday': 162,
#          'republic': 114,
#          'ireland': 222,
#          'fans': 31,
#          'awarded': 43,
#          'medal': 20,
#          'sportsmanship': 1,
#          'paris': 228,
#          'mayor': 145,
#          'afghan': 420,
#          'suicide': 329,
#          'bomber': 100,
#          'kills': 309,
#          '40': 247,
#          'bbc': 517,
#          'news': 1003,
#          'us': 3030,
#          'airstrikes': 69,
#          'kill': 444,
#          'least': 473,
#          '250': 38,
#          'isis': 702,
#          'fighters': 164,
#          'convoy': 35,
#          'outside': 183,
#          'fallujah': 12,
#          'official': 489,
#          'turkish': 383,
#          'cop': 45,
#          'took': 153,
#          'istanbul': 54,
#          'gunman': 57,
#          'hailed': 21,
#          'hero': 50,
#          'cannabis': 117,
#          'compounds': 1,
#          'could': 978,
#          'treat': 26,
#          'alzheimer': 5,
#          'removing': 29,
#          'plaque': 2,
#          'forming': 14,
#          'proteins': 4,
#          'brain': 58,
#          'cells': 51,
#          'research': 170,
#          'suggests': 101,
#          'japan': 791,
#          'top': 525,
#          'court': 1034,
#          'approved': 108,
#          'blanket': 13,
#          'surveillance': 288,
#          'country': 1218,
#          'muslims': 285,
#          'nothey': 27,
#          'made': 410,
#          'suspects': 92,
#          'never': 221,
#          'anything': 53,
#          'wrong': 125,
#          'japanese': 323,
#          'mohammed': 46,
#          'fujita': 1,
#          'cia': 294,
#          'gave': 95,
#          'romania': 53,
#          'millions': 223,
#          'host': 70,
#          'secret': 435,
#          'prisons': 34,
#          'groups': 245,
#          'urge': 57,
#          'united': 2402,
#          'nations': 570,
#          'suspend': 35,
#          'saudi': 765,
#          'arabia': 408,
#          'rights': 859,
#          'council': 185,
#          'googles': 2,
#          'free': 470,
#          'wifi': 7,
#          'indian': 397,
#          'railway': 33,
#          'stations': 42,
#          'better': 121,
#          'countrys': 100,
#          'paid': 149,
#          'services': 122,
#          'mounting': 28,
#          'evidence': 305,
#          'hobbits': 1,
#          'wiped': 36,
#          'modern': 99,
#          'humans': 87,
#          'ancestors': 9,
#          '50000': 51,
#          'years': 1544,
#          'ago': 255,
#          'carried': 77,
#          'tuesday': 280,
#          'terror': 316,
#          'ataturk': 1,
#          'airport': 188,
#          'russia': 1701,
#          'uzbekistan': 10,
#          'kyrgyzstan': 27,
#          'offical': 2,
#          'said': 1185,
#          'calls': 585,
#          'un': 1015,
#          'human': 817,
#          'military': 1114,
#          'aggresion': 1,
#          'yemen': 190,
#          '100': 354,
#          'nobel': 151,
#          'laureates': 7,
#          'call': 323,
#          'greenpeace': 46,
#          'anti': 825,
#          'gmo': 17,
#          'obstruction': 3,
#          'developing': 85,
#          'world': 2245,
#          'british': 861,
#          'pedophile': 36,
#          'sentenced': 258,
#          '85': 32,
#          'trafficking': 99,
#          'child': 479,
#          'abuse': 354,
#          'images': 117,
#          'domminich': 1,
#          'shaw': 3,
#          'kingpin': 14,
#          'sexual': 202,
#          'violence': 351,
#          'children': 773,
#          'sent': 166,
#          'dozens': 142,
#          'online': 271,
#          'discussed': 15,
#          'plans': 427,
#          'assault': 123,
#          'probation': 2,
#          'permitted': 20,
#          '200': 173,
#          'offshore': 74,
#          'fracks': 1,
#          'gulf': 116,
#          'mexico': 550,
#          '2010': 124,
#          '2014': 108,
#          'allowed': 163,
#          '72': 34,
#          'gallons': 13,
#          'chemical': 154,
#          'discharge': 6,
#          'swimming': 16,
#          'ridicule': 8,
#          'french': 652,
#          'beach': 47,
#          'police': 1963,
#          'carry': 77,
#          'guns': 58,
#          'trunks': 3,
#          'lifeguards': 1,
#          'frances': 22,
#          'busiest': 3,
#          'beaches': 22,
#          'bullet': 28,
#          'proof': 52,
#          'vests': 10,
#          'first': 1338,
#          'time': 762,
#          'summer': 58,
#          'amid': 215,
#          'fears': 177,
#          'terrorists': 171,
#          'target': 110,
#          'holidaymakers': 2,
#          'uefa': 3,
#          'minutes': 89,
#          'silence': 53,
#          'euro': 165,
#          '2016': 57,
#          'noturkey': 17,
#          'already': 168,
#          'eliminated': 10,
#          'law': 882,
#          'enforcement': 45,
#          'sources': 90,
#          'gun': 101,
#          'used': 429,
#          'attacks': 509,
#          'came': 87,
#          'phoenix': 3,
#          'explosion': 120,
#          'yemeni': 45,
#          'former': 637,
#          'president': 1422,
#          'terrorism': 205,
#          'offspring': 2,
#          'wahhabism': 3,
#          'al': 646,
#          'saud': 7,
#          'regime': 203,
#          'uk': 1427,
#          'must': 374,
#          'accept': 80,
#          'freedom': 230,
#          'movement': 101,
#          'access': 225,
#          'eu': 675,
#          'market': 189,
#          'devastated': 14,
#          'scientists': 401,
#          'late': 73,
#          'captive': 26,
#          'breed': 7,
#          'mammal': 10,
#          'lost': 231,
#          'climate': 423,
#          'change': 423,
#          'australian': 566,
#          'conservationists': 17,
#          'spent': 101,
#          '5': 575,
#          'months': 366,
#          'obtaining': 10,
#          'permissions': 1,
#          'planning': 142,
#          'breeding': 7,
#          'program': 179,
#          'arrived': 27,
#          'rodents': 2,
#          'tiny': 49,
#          'island': 154,
#          'labor': 91,
#          'leader': 609,
#          'jeremy': 21,
#          'corbyn': 15,
#          'loses': 96,
#          'confidence': 28,
#          'vote': 290,
#          'refuses': 129,
#          'resign': 75,
#          'shop': 31,
#          'firebombed': 7,
#          'inside': 186,
#          'mexican': 278,
#          'authorities': 309,
#          'sexually': 67,
#          'torture': 263,
#          'women': 869,
#          'prison': 459,
#          'shares': 37,
#          'pound': 30,
#          'continue': 136,
#          'recover': 15,
#          'iceland': 197,
#          'historian': 10,
#          'johannesson': 1,
#          'wins': 142,
#          'presidential': 133,
#          'election': 325,
#          '99': 46,
#          'million': 894,
#          'year': 1680,
#          'old': 916,
#          'bird': 37,
#          'wings': 8,
#          'found': 987,
#          'encased': 3,
#          'amber': 3,
#          'finding': 57,
#          'things': 67,
#          'trapped': 70,
#          'far': 276,
#          'rare': 135,
#          'researchers': 132,
#          'burma': 55,
#          'pair': 15,
#          'like': 569,
#          'frozen': 44,
#          'knew': 65,
#          'something': 85,
#          'special': 126,
#          'chatbot': 1,
#          'programmed': 2,
#          'teenager': 63,
#          'successfully': 60,
#          'challenged': 15,
#          '160000': 6,
#          'parking': 18,
#          'tickets': 11,
#          'since': 538,
#          'launch': 174,
#          'last': 696,
#          'philippine': 44,
#          'elect': 16,
#          'monday': 260,
#          'aggressively': 7,
#          'promote': 36,
#          'artificial': 29,
#          'birth': 95,
#          'control': 309,
#          'even': 458,
#          'risk': 161,
#          'getting': 153,
#          'fight': 357,
#          'dominant': 6,
#          'catholic': 221,
#          'church': 323,
#          'staunchly': 3,
#          'opposes': 21,
#          'contraceptives': 7,
#          'belgian': 61,
#          'prime': 547,
#          'minister': 1064,
#          'ridicules': 2,
#          'nigel': 10,
#          'farage': 10,
#          'accuses': 120,
#          'ukip': 6,
#          'lying': 35,
#          'referendum': 102,
#          'campaign': 237,
#          'brexiteer': 1,
#          'laughing': 9,
#          'islamic': 587,
#          'state': 1243,
#          'bombings': 52,
#          'southern': 158,
#          '38': 32,
#          'escape': 82,
#          'tunnel': 52,
#          'dug': 7,
#          'hand': 130,
#          'holocaust': 96,
#          'massacre': 200,
#          'site': 216,
#          'land': 321,
#          'beijing': 172,
#          'sinking': 30,
#          'much': 312,
#          'four': 387,
#          'inches': 10,
#          'per': 200,
#          'overconsumption': 3,
#          'groundwater': 12,
#          'according': 345,
#          'new': 2425,
#          'car': 233,
#          'bomb': 345,
#          'mosque': 123,
#          'perth': 8,
#          'australia': 559,
#          'emaciated': 4,
#          'lions': 29,
#          'taiz': 1,
#          'zoo': 43,
#          'blood': 123,
#          'soaked': 4,
#          'cages': 9,
#          'left': 285,
#          'starve': 17,
#          'due': 221,
#          'civil': 191,
#          'war': 1593,
#          'rupert': 81,
#          'murdoch': 171,
#          'describes': 26,
#          'brexit': 23,
#          'wonderful': 5,
#          'media': 461,
#          'mogul': 7,
#          'likened': 7,
#          'leaving': 117,
#          'break': 134,
#          'shared': 28,
#          'view': 77,
#          'donald': 27,
#          'trump': 43,
#          'able': 103,
#          'man': 928,
#          'killed': 1326,
#          'google': 324,
#          'disastrous': 12,
#          'symantec': 2,
#          'norton': 3,
#          'vulnerabilities': 2,
#          'bad': 139,
#          'gets': 271,
#          'extremist': 56,
#          'rise': 233,
#          'germany': 780,
#          'domestic': 68,
#          'intelligence': 334,
#          'agency': 271,
#          'right': 555,
#          'islamist': 139,
#          'radical': 84,
#          'gaining': 22,
#          'membership': 48,
#          'labour': 86,
#          'mps': 87,
#          'pass': 63,
#          'motion': 23,
#          'zealand': 233,
#          'town': 219,
#          'notoo': 17,
#          'many': 450,
#          'jobs': 102,
#          'launches': 131,
#          'drive': 85,
#          'recruit': 21,
#          'outsiders': 7,
#          '500': 193,
#          'want': 365,
#          'save': 177,
#          'great': 231,
#          'barrier': 82,
#          'reef': 93,
#          'stop': 443,
#          'supporting': 51,
#          'coal': 151,
#          'personal': 132,
#          'details': 87,
#          '112': 12,
#          '000': 804,
#          'officers': 217,
#          'uploaded': 10,
#          'security': 613,
#          'breach': 47,
#          'fortnight': 3,
#          'two': 1149,
#          'murdered': 119,
#          'home': 423,
#          'jihadist': 24,
#          'sp': 16,
#          'cuts': 166,
#          'kingdom': 148,
#          'sovereign': 40,
#          'credit': 85,
#          'rating': 39,
#          'aa': 1,
#          'aaa': 9,
#          'huge': 213,
#          'helium': 6,
#          'deposit': 10,
#          'africa': 428,
#          'ceo': 72,
#          'south': 929,
#          'african': 287,
#          'broadcaster': 18,
#          'quits': 41,
#          'shortly': 20,
#          'negative': 34,
#          'banned': 300,
#          'cost': 159,
#          'investors': 43,
#          'trillion': 85,
#          'worst': 193,
#          'one': 1415,
#          'day': 528,
#          'drop': 100,
#          'ever': 301,
#          'hong': 170,
#          'kong': 163,
#          'democracy': 218,
#          'activists': 285,
#          'return': 210,
#          'rule': 119,
#          'step': 129,
#          'independence': 117,
#          'join': 190,
#          'notriangle': 1,
#          'non': 168,
#          'countries': 537,
#          'osborne': 7,
#          'absolutely': 26,
#          'going': 260,
#          'cut': 272,
#          'spending': 88,
#          'raise': 104,
#          'taxes': 93,
#          'wouldo': 12,
#          'let': 160,
#          'scotland': 134,
#          'scottish': 68,
#          'mep': 7,
#          'alyn': 1,
#          'smith': 12,
#          'urged': 70,
#          'members': 262,
#          'european': 598,
#          'parliament': 457,
#          'stand': 109,
#          'hit': 380,
#          'history': 271,
#          'making': 240,
#          'dollar': 107,
#          'parity': 4,
#          'end': 515,
#          'merkel': 143,
#          'vows': 103,
#          'strengthen': 18,
#          'tells': 235,
#          'cherry': 3,
#          'picking': 11,
#          'ryanair': 8,
#          'deploy': 33,
#          'aircraft': 128,
#          'routes': 18,
#          'next': 318,
#          '2017': 17,
#          'instead': 136,
#          'focus': 32,
#          'union': 270,
#          'destroy': 116,
#          'larry': 4,
#          'king': 164,
#          'siemens': 5,
#          'freezes': 19,
#          'wind': 115,
#          'power': 593,
#          'investment': 59,
#          'canada': 679,
#          'pledge': 54,
#          '50': 308,
#          'clean': 122,
#          'energy': 350,
#          '2025': 10,
#          'increasing': 58,
#          'torturing': 26,
#          'refugees': 218,
#          'medical': 167,
#          'experts': 164,
#          'claim': 215,
#          'richard': 53,
#          'branson': 12,
#          'founder': 183,
#          'virgin': 27,
#          'group': 591,
#          'company': 351,
#          'third': 193,
#          'value': 53,
#          'voted': 91,
#          'leave': 228,
#          'week': 362,
#          '37': 28,
#          'skull': 16,
#          'borneo': 11,
#          'reveals': 199,
#          'surprise': 56,
#          'study': 301,
#          'deep': 94,
#          'oldest': 71,
#          'discovered': 209,
#          'se': 11,
#          'asia': 129,
#          'ancient': 170,
#          'person': 127,
#          'related': 78,
#          'indigenous': 84,
#          'australians': 38,
#          'originally': 16,
#          'thought': 159,
#          'discovery': 72,
#          'game': 91,
#          'changer': 6,
#          'palestinians': 375,
#          'stone': 46,
#          'western': 288,
#          'wall': 126,
#          'worshipers': 3,
#          'shut': 146,
#          'temple': 53,
#          'mount': 48,
#          'jean': 20,
#          'claude': 3,
#          'juncker': 3,
#          'asks': 130,
#          'romanians': 7,
#          'remainians': 1,
#          'offering': 32,
#          '48': 50,
#          'britons': 41,
#          'bucharest': 8,
#          'newspaper': 182,
#          'app': 30,
#          'connects': 5,
#          'loving': 5,
#          'romanian': 28,
#          'families': 141,
#          'needy': 4,
#          'brits': 17,
#          'allowing': 103,
#          'offer': 78,
#          'help': 436,
#          'immigrants': 67,
#          'apply': 31,
#          'id': 43,
#          'gibraltar': 8,
#          'talks': 244,
#          '8': 311,
#          'bombers': 81,
#          'strike': 416,
#          'lebanon': 118,
#          'forces': 654,
#          'routinely': 18,
#          'isexual': 3,
#          'amnesty': 112,
#          'international': 681,
#          'compiled': 3,
#          'testimonies': 5,
#          'despite': 301,
#          'thousands': 544,
#          'complaints': 38,
#          '15': 299,
#          'probes': 14,
#          'led': 197,
#          'criminal': 206,
#          'convictions': 12,
#          '1991': 5,
#          'barclays': 23,
#          'rbs': 14,
#          'suspended': 74,
#          'trading': 49,
#          'tanking': 5,
#          'pope': 343,
#          'ask': 98,
#          'forgiveness': 6,
#          'gays': 60,
#          'poland': 155,
#          'ishocked': 3,
#          'xenophobic': 5,
#          'poles': 9,
#          'second': 267,
#          'cabinet': 88,
#          'agrees': 59,
#          'welcome': 60,
#          'ally': 58,
#          'sterling': 2,
#          'dips': 5,
#          '31': 42,
#          'low': 147,
#          'uncertainty': 4,
#          'surge': 42,
#          'hate': 73,
#          'crimes': 318,
#          'weapons': 415,
#          'shipped': 9,
#          'jordan': 93,
#          'intended': 30,
#          'syrian': 610,
#          'rebels': 363,
#          'systematically': 15,
#          'stolen': 113,
#          'jordanian': 22,
#          'operatives': 13,
#          'sold': 127,
#          'arms': 247,
#          'merchants': 5,
#          'black': 224,
#          'american': 549,
#          'officials': 601,
#          'angela': 66,
#          'file': 69,
#          'exit': 46,
#          'papers': 96,
#          'begin': 95,
#          'hope': 78,
#          'threatened': 146,
#          'species': 115,
#          'aquarium': 3,
#          'osaka': 5,
#          'succeeded': 10,
#          'artificially': 7,
#          'rockhopper': 2,
#          'penguin': 8,
#          'sky': 44,
#          'journalist': 215,
#          'speechless': 6,
#          'mp': 135,
#          'nothere': 22,
#          'plan': 347,
#          'giant': 170,
#          'panda': 11,
#          'macau': 1,
#          'gives': 140,
#          'twins': 9,
#          'get': 467,
#          'britain': 490,
#          'invoke': 3,
#          'article': 98,
#          'sea': 391,
#          'turtle': 17,
#          'beaten': 128,
#          'dead': 737,
#          'taking': 215,
#          'selfies': 2,
#          'loggerhead': 2,
#          'receiving': 29,
#          'sticks': 15,
#          'stepped': 18,
#          'german': 701,
#          'lawyers': 75,
#          'probe': 143,
#          'erdogan': 129,
#          'alleged': 197,
#          'intensify': 11,
#          'cooperation': 42,
#          'fellow': 27,
#          'supporters': 86,
#          '52': 36,
#          'win': 132,
#          'entirely': 28,
#          'overwhelming': 19,
#          'calling': 181,
#          'government': 2076,
#          'hold': 143,
#          'prevent': 142,
#          'irreversible': 16,
#          'damage': 108,
#          'turkey': 544,
#          'isorry': 2,
#          'downing': 25,
#          'russian': 1222,
#          'jet': 98,
#          'edward': 182,
#          'snowden': 445,
#          'lawyer': 121,
#          'push': 101,
#          'pardon': 13,
#          'obama': 533,
#          'opinion': 52,
#          'poll': 132,
#          'majority': 108,
#          'half': 277,
#          'adults': 33,
#          'say': 852,
#          'happy': 41,
#          'result': 114,
#          'five': 400,
#          '43': 61,
#          'saying': 243,
#          'unhappy': 13,
#          'outcome': 13,
#          'conservative': 101,
#          'campaigner': 13,
#          'post': 207,
#          'economists': 20,
#          'predict': 19,
#          'recession': 77,
#          'weakening': 9,
#          'isuperstate': 1,
#          'france': 659,
#          'creating': 71,
#          'superstate': 2,
#          'limiting': 12,
#          'powers': 116,
#          'individual': 25,
#          'britains': 24,
#          'decision': 124,
#          'pakistani': 238,
#          'clerics': 39,
#          'declare': 55,
#          'transgender': 17,
#          'marriages': 29,
#          'legal': 285,
#          'david': 217,
#          'cameron': 181,
#          'pm': 356,
#          'forecasts': 8,
#          'votes': 114,
#          'nicola': 4,
#          'sturgeon': 5,
#          'highly': 72,
#          'likely': 217,
#          'largest': 394,
#          'tibetan': 47,
#          'buddhist': 32,
#          'institute': 35,
#          'ordered': 209,
#          'demolished': 10,
#          'chinese': 967,
#          'single': 132,
#          'place': 183,
#          'rich': 164,
#          'richer': 17,
#          'expense': 15,
#          'poor': 195,
#          'oxfam': 18,
#          'warns': 362,
#          'spanish': 165,
#          'returned': 48,
#          'spain': 267,
#          'back': 554,
#          'drops': 66,
#          'nearly': 296,
#          'strong': 83,
#          'results': 81,
#          'newcastle': 3,
#          'jk': 2,
#          'rowling': 2,
#          'leads': 61,
#          'charge': 131,
#          'buenos': 12,
#          'aires': 12,
#          'close': 200,
#          '140': 24,
#          'captivity': 5,
#          'degrading': 5,
#          'horacio': 1,
#          'rodrguez': 1,
#          'larreta': 1,
#          'zoos': 5,
#          'animals': 117,
#          'gradually': 4,
#          'moved': 45,
#          'nature': 63,
#          'reserves': 57,
#          'argentina': 137,
#          'provide': 84,
#          'suitable': 5,
#          'northern': 251,
#          'deputy': 64,
#          'polls': 30,
#          'polling': 10,
#          'happened': 62,
#          'petition': 59,
#          'popular': 87,
#          'crashing': 7,
#          'north': 1271,
#          'korea': 1214,
#          'printing': 16,
#          'massive': 237,
#          'amounts': 37,
#          'fake': 134,
#          'currency': 121,
#          'defectors': 27,
#          'sinn': 5,
#          'fein': 6,
#          'irish': 192,
#          'reunification': 16,
#          '70': 133,
#          'sharemarket': 1,
#          'disowns': 2,
#          '350m': 1,
#          'nhs': 41,
#          'hours': 266,
#          'soon': 138,
#          'possible': 184,
#          '350': 21,
#          'fund': 135,
#          'big': 269,
#          'mistake': 47,
#          'captions': 1,
#          'takes': 177,
#          'every': 299,
#          'send': 155,
#          'stamped': 2,
#          'material': 64,
#          'london': 425,
#          'banking': 95,
#          'job': 134,
#          'start': 161,
#          'large': 186,
#          'spike': 13,
#          'searches': 22,
#          'passport': 43,
#          'applications': 12,
#          'broke': 74,
#          'backs': 67,
#          'remain': 85,
#          '94': 17,
#          'night': 149,
#          'residents': 142,
#          'guilty': 193,
#          'insulting': 81,
#          'recep': 24,
#          'tayyip': 28,
#          'depicting': 14,
#          'gollum': 2,
#          'character': 15,
#          'lord': 57,
#          'rings': 12,
#          'antalya': 1,
#          'province': 77,
#          'rifat': 1,
#          'cetin': 1,
#          'jail': 322,
#          'sentence': 122,
#          'stripped': 42,
#          'parental': 7,
#          'custody': 54,
#          'today': 363,
#          'decides': 31,
#          'whether': 128,
#          'e': 87,
#          'cigarettes': 32,
#          'public': 567,
#          'warn': 93,
#          'ban': 637,
#          'using': 345,
#          'places': 57,
#          'damaging': 29,
#          'may': 863,
#          'put': 216,
#          ...})

# %% [markdown]
# # A note on Word Embeddings

# %% [markdown]
# ![word_embed](resources/wordvectors.png)

# %% [markdown]
# **Reference**: https://nlp.stanford.edu/projects/glove/

# %% [markdown]
# ## We are going to use Glove embeddings to initialize our weights while designing our neural network. Let's load the same so that we can ensure our headline corpus' vocabulary matches where possible with Glove Embedding vocabulary.

# %%
# Load GloVe's embeddings
embeddings_index = {}
with open('glove.6B.300d.txt', encoding='utf-8') as f:
    for line in f:
        values = line.split(' ')
        word = values[0]
        embedding = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = embedding

print('Word embeddings:', len(embeddings_index))
# Out:
# Word embeddings: 400000

# %% [markdown]
# ## It is not necessary that we will have embeddings for all the words in Glove. So to limit such cases by limiting vocabulary by applying simple logic:  Remove the words that are "rare" and are not available in Glove

# %%
# Limit the vocab that we will use to words that appear ≥ threshold or are in GloVe

# Define threshold
threshold = 10

#dictionary to convert words to integers
vocab_to_int = {} 

value = 0
for word, count in word_counts.items():
    if count >= threshold or word in embeddings_index:
        vocab_to_int[word] = value
        value += 1

# %%
vocab_to_int
# Out:
# {'jamaica': 0,
#  'proposes': 1,
#  'marijuana': 2,
#  'dispensers': 3,
#  'tourists': 4,
#  'airports': 5,
#  'following': 6,
#  'legalisation': 7,
#  'kiosks': 8,
#  'desks': 9,
#  'would': 10,
#  'give': 11,
#  'people': 12,
#  'license': 13,
#  'purchase': 14,
#  '2': 15,
#  'ounces': 16,
#  'drug': 17,
#  'use': 18,
#  'stay': 19,
#  'stephen': 20,
#  'hawking': 21,
#  'says': 22,
#  'pollution': 23,
#  'still': 24,
#  'biggest': 25,
#  'threats': 26,
#  'mankind': 27,
#  'certainly': 28,
#  'become': 29,
#  'less': 30,
#  'greedy': 31,
#  'stupid': 32,
#  'treatment': 33,
#  'environment': 34,
#  'past': 35,
#  'decade': 36,
#  'boris': 37,
#  'johnson': 38,
#  'run': 39,
#  'tory': 40,
#  'party': 41,
#  'leadership': 42,
#  'six': 43,
#  'gay': 44,
#  'men': 45,
#  'ivory': 46,
#  'coast': 47,
#  'abused': 48,
#  'forced': 49,
#  'flee': 50,
#  'homes': 51,
#  'pictured': 52,
#  'signing': 53,
#  'condolence': 54,
#  'book': 55,
#  'victims': 56,
#  'recent': 57,
#  'attack': 58,
#  'nightclub': 59,
#  'florida': 60,
#  'switzerland': 61,
#  'denies': 62,
#  'citizenship': 63,
#  'muslim': 64,
#  'immigrant': 65,
#  'girls': 66,
#  'refused': 67,
#  'swim': 68,
#  'boys': 69,
#  'report': 70,
#  'palestinian': 71,
#  'terrorist': 72,
#  'stabs': 73,
#  'israeli': 74,
#  'teen': 75,
#  'girl': 76,
#  'death': 77,
#  'bedroom': 78,
#  'puerto': 79,
#  'rico': 80,
#  'default': 81,
#  '$': 82,
#  '1': 83,
#  'billion': 84,
#  'debt': 85,
#  'friday': 86,
#  'republic': 87,
#  'ireland': 88,
#  'fans': 89,
#  'awarded': 90,
#  'medal': 91,
#  'sportsmanship': 92,
#  'paris': 93,
#  'mayor': 94,
#  'afghan': 95,
#  'suicide': 96,
#  'bomber': 97,
#  'kills': 98,
#  '40': 99,
#  'bbc': 100,
#  'news': 101,
#  'us': 102,
#  'airstrikes': 103,
#  'kill': 104,
#  'least': 105,
#  '250': 106,
#  'isis': 107,
#  'fighters': 108,
#  'convoy': 109,
#  'outside': 110,
#  'fallujah': 111,
#  'official': 112,
#  'turkish': 113,
#  'cop': 114,
#  'took': 115,
#  'istanbul': 116,
#  'gunman': 117,
#  'hailed': 118,
#  'hero': 119,
#  'cannabis': 120,
#  'compounds': 121,
#  'could': 122,
#  'treat': 123,
#  'alzheimer': 124,
#  'removing': 125,
#  'plaque': 126,
#  'forming': 127,
#  'proteins': 128,
#  'brain': 129,
#  'cells': 130,
#  'research': 131,
#  'suggests': 132,
#  'japan': 133,
#  'top': 134,
#  'court': 135,
#  'approved': 136,
#  'blanket': 137,
#  'surveillance': 138,
#  'country': 139,
#  'muslims': 140,
#  'nothey': 141,
#  'made': 142,
#  'suspects': 143,
#  'never': 144,
#  'anything': 145,
#  'wrong': 146,
#  'japanese': 147,
#  'mohammed': 148,
#  'fujita': 149,
#  'cia': 150,
#  'gave': 151,
#  'romania': 152,
#  'millions': 153,
#  'host': 154,
#  'secret': 155,
#  'prisons': 156,
#  'groups': 157,
#  'urge': 158,
#  'united': 159,
#  'nations': 160,
#  'suspend': 161,
#  'saudi': 162,
#  'arabia': 163,
#  'rights': 164,
#  'council': 165,
#  'googles': 166,
#  'free': 167,
#  'wifi': 168,
#  'indian': 169,
#  'railway': 170,
#  'stations': 171,
#  'better': 172,
#  'countrys': 173,
#  'paid': 174,
#  'services': 175,
#  'mounting': 176,
#  'evidence': 177,
#  'hobbits': 178,
#  'wiped': 179,
#  'modern': 180,
#  'humans': 181,
#  'ancestors': 182,
#  '50000': 183,
#  'years': 184,
#  'ago': 185,
#  'carried': 186,
#  'tuesday': 187,
#  'terror': 188,
#  'ataturk': 189,
#  'airport': 190,
#  'russia': 191,
#  'uzbekistan': 192,
#  'kyrgyzstan': 193,
#  'offical': 194,
#  'said': 195,
#  'calls': 196,
#  'un': 197,
#  'human': 198,
#  'military': 199,
#  'yemen': 200,
#  '100': 201,
#  'nobel': 202,
#  'laureates': 203,
#  'call': 204,
#  'greenpeace': 205,
#  'anti': 206,
#  'gmo': 207,
#  'obstruction': 208,
#  'developing': 209,
#  'world': 210,
#  'british': 211,
#  'pedophile': 212,
#  'sentenced': 213,
#  '85': 214,
#  'trafficking': 215,
#  'child': 216,
#  'abuse': 217,
#  'images': 218,
#  'shaw': 219,
#  'kingpin': 220,
#  'sexual': 221,
#  'violence': 222,
#  'children': 223,
#  'sent': 224,
#  'dozens': 225,
#  'online': 226,
#  'discussed': 227,
#  'plans': 228,
#  'assault': 229,
#  'probation': 230,
#  'permitted': 231,
#  '200': 232,
#  'offshore': 233,
#  'gulf': 234,
#  'mexico': 235,
#  '2010': 236,
#  '2014': 237,
#  'allowed': 238,
#  '72': 239,
#  'gallons': 240,
#  'chemical': 241,
#  'discharge': 242,
#  'swimming': 243,
#  'ridicule': 244,
#  'french': 245,
#  'beach': 246,
#  'police': 247,
#  'carry': 248,
#  'guns': 249,
#  'trunks': 250,
#  'lifeguards': 251,
#  'frances': 252,
#  'busiest': 253,
#  'beaches': 254,
#  'bullet': 255,
#  'proof': 256,
#  'vests': 257,
#  'first': 258,
#  'time': 259,
#  'summer': 260,
#  'amid': 261,
#  'fears': 262,
#  'terrorists': 263,
#  'target': 264,
#  'holidaymakers': 265,
#  'uefa': 266,
#  'minutes': 267,
#  'silence': 268,
#  'euro': 269,
#  '2016': 270,
#  'noturkey': 271,
#  'already': 272,
#  'eliminated': 273,
#  'law': 274,
#  'enforcement': 275,
#  'sources': 276,
#  'gun': 277,
#  'used': 278,
#  'attacks': 279,
#  'came': 280,
#  'phoenix': 281,
#  'explosion': 282,
#  'yemeni': 283,
#  'former': 284,
#  'president': 285,
#  'terrorism': 286,
#  'offspring': 287,
#  'wahhabism': 288,
#  'al': 289,
#  'saud': 290,
#  'regime': 291,
#  'uk': 292,
#  'must': 293,
#  'accept': 294,
#  'freedom': 295,
#  'movement': 296,
#  'access': 297,
#  'eu': 298,
#  'market': 299,
#  'devastated': 300,
#  'scientists': 301,
#  'late': 302,
#  'captive': 303,
#  'breed': 304,
#  'mammal': 305,
#  'lost': 306,
#  'climate': 307,
#  'change': 308,
#  'australian': 309,
#  'conservationists': 310,
#  'spent': 311,
#  '5': 312,
#  'months': 313,
#  'obtaining': 314,
#  'permissions': 315,
#  'planning': 316,
#  'breeding': 317,
#  'program': 318,
#  'arrived': 319,
#  'rodents': 320,
#  'tiny': 321,
#  'island': 322,
#  'labor': 323,
#  'leader': 324,
#  'jeremy': 325,
#  'corbyn': 326,
#  'loses': 327,
#  'confidence': 328,
#  'vote': 329,
#  'refuses': 330,
#  'resign': 331,
#  'shop': 332,
#  'firebombed': 333,
#  'inside': 334,
#  'mexican': 335,
#  'authorities': 336,
#  'sexually': 337,
#  'torture': 338,
#  'women': 339,
#  'prison': 340,
#  'shares': 341,
#  'pound': 342,
#  'continue': 343,
#  'recover': 344,
#  'iceland': 345,
#  'historian': 346,
#  'johannesson': 347,
#  'wins': 348,
#  'presidential': 349,
#  'election': 350,
#  '99': 351,
#  'million': 352,
#  'year': 353,
#  'old': 354,
#  'bird': 355,
#  'wings': 356,
#  'found': 357,
#  'encased': 358,
#  'amber': 359,
#  'finding': 360,
#  'things': 361,
#  'trapped': 362,
#  'far': 363,
#  'rare': 364,
#  'researchers': 365,
#  'burma': 366,
#  'pair': 367,
#  'like': 368,
#  'frozen': 369,
#  'knew': 370,
#  'something': 371,
#  'special': 372,
#  'programmed': 373,
#  'teenager': 374,
#  'successfully': 375,
#  'challenged': 376,
#  'parking': 377,
#  'tickets': 378,
#  'since': 379,
#  'launch': 380,
#  'last': 381,
#  'philippine': 382,
#  'elect': 383,
#  'monday': 384,
#  'aggressively': 385,
#  'promote': 386,
#  'artificial': 387,
#  'birth': 388,
#  'control': 389,
#  'even': 390,
#  'risk': 391,
#  'getting': 392,
#  'fight': 393,
#  'dominant': 394,
#  'catholic': 395,
#  'church': 396,
#  'staunchly': 397,
#  'opposes': 398,
#  'contraceptives': 399,
#  'belgian': 400,
#  'prime': 401,
#  'minister': 402,
#  'ridicules': 403,
#  'nigel': 404,
#  'farage': 405,
#  'accuses': 406,
#  'ukip': 407,
#  'lying': 408,
#  'referendum': 409,
#  'campaign': 410,
#  'laughing': 411,
#  'islamic': 412,
#  'state': 413,
#  'bombings': 414,
#  'southern': 415,
#  '38': 416,
#  'escape': 417,
#  'tunnel': 418,
#  'dug': 419,
#  'hand': 420,
#  'holocaust': 421,
#  'massacre': 422,
#  'site': 423,
#  'land': 424,
#  'beijing': 425,
#  'sinking': 426,
#  'much': 427,
#  'four': 428,
#  'inches': 429,
#  'per': 430,
#  'overconsumption': 431,
#  'groundwater': 432,
#  'according': 433,
#  'new': 434,
#  'car': 435,
#  'bomb': 436,
#  'mosque': 437,
#  'perth': 438,
#  'australia': 439,
#  'emaciated': 440,
#  'lions': 441,
#  'taiz': 442,
#  'zoo': 443,
#  'blood': 444,
#  'soaked': 445,
#  'cages': 446,
#  'left': 447,
#  'starve': 448,
#  'due': 449,
#  'civil': 450,
#  'war': 451,
#  'rupert': 452,
#  'murdoch': 453,
#  'describes': 454,
#  'brexit': 455,
#  'wonderful': 456,
#  'media': 457,
#  'mogul': 458,
#  'likened': 459,
#  'leaving': 460,
#  'break': 461,
#  'shared': 462,
#  'view': 463,
#  'donald': 464,
#  'trump': 465,
#  'able': 466,
#  'man': 467,
#  'killed': 468,
#  'google': 469,
#  'disastrous': 470,
#  'symantec': 471,
#  'norton': 472,
#  'vulnerabilities': 473,
#  'bad': 474,
#  'gets': 475,
#  'extremist': 476,
#  'rise': 477,
#  'germany': 478,
#  'domestic': 479,
#  'intelligence': 480,
#  'agency': 481,
#  'right': 482,
#  'islamist': 483,
#  'radical': 484,
#  'gaining': 485,
#  'membership': 486,
#  'labour': 487,
#  'mps': 488,
#  'pass': 489,
#  'motion': 490,
#  'zealand': 491,
#  'town': 492,
#  'notoo': 493,
#  'many': 494,
#  'jobs': 495,
#  'launches': 496,
#  'drive': 497,
#  'recruit': 498,
#  'outsiders': 499,
#  '500': 500,
#  'want': 501,
#  'save': 502,
#  'great': 503,
#  'barrier': 504,
#  'reef': 505,
#  'stop': 506,
#  'supporting': 507,
#  'coal': 508,
#  'personal': 509,
#  'details': 510,
#  '112': 511,
#  '000': 512,
#  'officers': 513,
#  'uploaded': 514,
#  'security': 515,
#  'breach': 516,
#  'fortnight': 517,
#  'two': 518,
#  'murdered': 519,
#  'home': 520,
#  'jihadist': 521,
#  'sp': 522,
#  'cuts': 523,
#  'kingdom': 524,
#  'sovereign': 525,
#  'credit': 526,
#  'rating': 527,
#  'aa': 528,
#  'aaa': 529,
#  'huge': 530,
#  'helium': 531,
#  'deposit': 532,
#  'africa': 533,
#  'ceo': 534,
#  'south': 535,
#  'african': 536,
#  'broadcaster': 537,
#  'quits': 538,
#  'shortly': 539,
#  'negative': 540,
#  'banned': 541,
#  'cost': 542,
#  'investors': 543,
#  'trillion': 544,
#  'worst': 545,
#  'one': 546,
#  'day': 547,
#  'drop': 548,
#  'ever': 549,
#  'hong': 550,
#  'kong': 551,
#  'democracy': 552,
#  'activists': 553,
#  'return': 554,
#  'rule': 555,
#  'step': 556,
#  'independence': 557,
#  'join': 558,
#  'non': 559,
#  'countries': 560,
#  'osborne': 561,
#  'absolutely': 562,
#  'going': 563,
#  'cut': 564,
#  'spending': 565,
#  'raise': 566,
#  'taxes': 567,
#  'wouldo': 568,
#  'let': 569,
#  'scotland': 570,
#  'scottish': 571,
#  'mep': 572,
#  'alyn': 573,
#  'smith': 574,
#  'urged': 575,
#  'members': 576,
#  'european': 577,
#  'parliament': 578,
#  'stand': 579,
#  'hit': 580,
#  'history': 581,
#  'making': 582,
#  'dollar': 583,
#  'parity': 584,
#  'end': 585,
#  'merkel': 586,
#  'vows': 587,
#  'strengthen': 588,
#  'tells': 589,
#  'cherry': 590,
#  'picking': 591,
#  'ryanair': 592,
#  'deploy': 593,
#  'aircraft': 594,
#  'routes': 595,
#  'next': 596,
#  '2017': 597,
#  'instead': 598,
#  'focus': 599,
#  'union': 600,
#  'destroy': 601,
#  'larry': 602,
#  'king': 603,
#  'siemens': 604,
#  'freezes': 605,
#  'wind': 606,
#  'power': 607,
#  'investment': 608,
#  'canada': 609,
#  'pledge': 610,
#  '50': 611,
#  'clean': 612,
#  'energy': 613,
#  '2025': 614,
#  'increasing': 615,
#  'torturing': 616,
#  'refugees': 617,
#  'medical': 618,
#  'experts': 619,
#  'claim': 620,
#  'richard': 621,
#  'branson': 622,
#  'founder': 623,
#  'virgin': 624,
#  'group': 625,
#  'company': 626,
#  'third': 627,
#  'value': 628,
#  'voted': 629,
#  'leave': 630,
#  'week': 631,
#  '37': 632,
#  'skull': 633,
#  'borneo': 634,
#  'reveals': 635,
#  'surprise': 636,
#  'study': 637,
#  'deep': 638,
#  'oldest': 639,
#  'discovered': 640,
#  'se': 641,
#  'asia': 642,
#  'ancient': 643,
#  'person': 644,
#  'related': 645,
#  'indigenous': 646,
#  'australians': 647,
#  'originally': 648,
#  'thought': 649,
#  'discovery': 650,
#  'game': 651,
#  'changer': 652,
#  'palestinians': 653,
#  'stone': 654,
#  'western': 655,
#  'wall': 656,
#  'worshipers': 657,
#  'shut': 658,
#  'temple': 659,
#  'mount': 660,
#  'jean': 661,
#  'claude': 662,
#  'juncker': 663,
#  'asks': 664,
#  'romanians': 665,
#  'offering': 666,
#  '48': 667,
#  'britons': 668,
#  'bucharest': 669,
#  'newspaper': 670,
#  'app': 671,
#  'connects': 672,
#  'loving': 673,
#  'romanian': 674,
#  'families': 675,
#  'needy': 676,
#  'brits': 677,
#  'allowing': 678,
#  'offer': 679,
#  'help': 680,
#  'immigrants': 681,
#  'apply': 682,
#  'id': 683,
#  'gibraltar': 684,
#  'talks': 685,
#  '8': 686,
#  'bombers': 687,
#  'strike': 688,
#  'lebanon': 689,
#  'forces': 690,
#  'routinely': 691,
#  'amnesty': 692,
#  'international': 693,
#  'compiled': 694,
#  'testimonies': 695,
#  'despite': 696,
#  'thousands': 697,
#  'complaints': 698,
#  '15': 699,
#  'probes': 700,
#  'led': 701,
#  'criminal': 702,
#  'convictions': 703,
#  '1991': 704,
#  'barclays': 705,
#  'rbs': 706,
#  'suspended': 707,
#  'trading': 708,
#  'tanking': 709,
#  'pope': 710,
#  'ask': 711,
#  'forgiveness': 712,
#  'gays': 713,
#  'poland': 714,
#  'xenophobic': 715,
#  'poles': 716,
#  'second': 717,
#  'cabinet': 718,
#  'agrees': 719,
#  'welcome': 720,
#  'ally': 721,
#  'sterling': 722,
#  'dips': 723,
#  '31': 724,
#  'low': 725,
#  'uncertainty': 726,
#  'surge': 727,
#  'hate': 728,
#  'crimes': 729,
#  'weapons': 730,
#  'shipped': 731,
#  'jordan': 732,
#  'intended': 733,
#  'syrian': 734,
#  'rebels': 735,
#  'systematically': 736,
#  'stolen': 737,
#  'jordanian': 738,
#  'operatives': 739,
#  'sold': 740,
#  'arms': 741,
#  'merchants': 742,
#  'black': 743,
#  'american': 744,
#  'officials': 745,
#  'angela': 746,
#  'file': 747,
#  'exit': 748,
#  'papers': 749,
#  'begin': 750,
#  'hope': 751,
#  'threatened': 752,
#  'species': 753,
#  'aquarium': 754,
#  'osaka': 755,
#  'succeeded': 756,
#  'artificially': 757,
#  'rockhopper': 758,
#  'penguin': 759,
#  'sky': 760,
#  'journalist': 761,
#  'speechless': 762,
#  'mp': 763,
#  'nothere': 764,
#  'plan': 765,
#  'giant': 766,
#  'panda': 767,
#  'macau': 768,
#  'gives': 769,
#  'twins': 770,
#  'get': 771,
#  'britain': 772,
#  'invoke': 773,
#  'article': 774,
#  'sea': 775,
#  'turtle': 776,
#  'beaten': 777,
#  'dead': 778,
#  'taking': 779,
#  'loggerhead': 780,
#  'receiving': 781,
#  'sticks': 782,
#  'stepped': 783,
#  'german': 784,
#  'lawyers': 785,
#  'probe': 786,
#  'erdogan': 787,
#  'alleged': 788,
#  'intensify': 789,
#  'cooperation': 790,
#  'fellow': 791,
#  'supporters': 792,
#  '52': 793,
#  'win': 794,
#  'entirely': 795,
#  'overwhelming': 796,
#  'calling': 797,
#  'government': 798,
#  'hold': 799,
#  'prevent': 800,
#  'irreversible': 801,
#  'damage': 802,
#  'turkey': 803,
#  'downing': 804,
#  'russian': 805,
#  'jet': 806,
#  'edward': 807,
#  'snowden': 808,
#  'lawyer': 809,
#  'push': 810,
#  'pardon': 811,
#  'obama': 812,
#  'opinion': 813,
#  'poll': 814,
#  'majority': 815,
#  'half': 816,
#  'adults': 817,
#  'say': 818,
#  'happy': 819,
#  'result': 820,
#  'five': 821,
#  '43': 822,
#  'saying': 823,
#  'unhappy': 824,
#  'outcome': 825,
#  'conservative': 826,
#  'campaigner': 827,
#  'post': 828,
#  'economists': 829,
#  'predict': 830,
#  'recession': 831,
#  'weakening': 832,
#  'france': 833,
#  'creating': 834,
#  'superstate': 835,
#  'limiting': 836,
#  'powers': 837,
#  'individual': 838,
#  'britains': 839,
#  'decision': 840,
#  'pakistani': 841,
#  'clerics': 842,
#  'declare': 843,
#  'transgender': 844,
#  'marriages': 845,
#  'legal': 846,
#  'david': 847,
#  'cameron': 848,
#  'pm': 849,
#  'forecasts': 850,
#  'votes': 851,
#  'nicola': 852,
#  'sturgeon': 853,
#  'highly': 854,
#  'likely': 855,
#  'largest': 856,
#  'tibetan': 857,
#  'buddhist': 858,
#  'institute': 859,
#  'ordered': 860,
#  'demolished': 861,
#  'chinese': 862,
#  'single': 863,
#  'place': 864,
#  'rich': 865,
#  'richer': 866,
#  'expense': 867,
#  'poor': 868,
#  'oxfam': 869,
#  'warns': 870,
#  'spanish': 871,
#  'returned': 872,
#  'spain': 873,
#  'back': 874,
#  'drops': 875,
#  'nearly': 876,
#  'strong': 877,
#  'results': 878,
#  'newcastle': 879,
#  'jk': 880,
#  'rowling': 881,
#  'leads': 882,
#  'charge': 883,
#  'buenos': 884,
#  'aires': 885,
#  'close': 886,
#  '140': 887,
#  'captivity': 888,
#  'degrading': 889,
#  'horacio': 890,
#  'zoos': 891,
#  'animals': 892,
#  'gradually': 893,
#  'moved': 894,
#  'nature': 895,
#  'reserves': 896,
#  'argentina': 897,
#  'provide': 898,
#  'suitable': 899,
#  'northern': 900,
#  'deputy': 901,
#  'polls': 902,
#  'polling': 903,
#  'happened': 904,
#  'petition': 905,
#  'popular': 906,
#  'crashing': 907,
#  'north': 908,
#  'korea': 909,
#  'printing': 910,
#  'massive': 911,
#  'amounts': 912,
#  'fake': 913,
#  'currency': 914,
#  'defectors': 915,
#  'sinn': 916,
#  'fein': 917,
#  'irish': 918,
#  'reunification': 919,
#  '70': 920,
#  'sharemarket': 921,
#  'disowns': 922,
#  '350m': 923,
#  'nhs': 924,
#  'hours': 925,
#  'soon': 926,
#  'possible': 927,
#  '350': 928,
#  'fund': 929,
#  'big': 930,
#  'mistake': 931,
#  'captions': 932,
#  'takes': 933,
#  'every': 934,
#  'send': 935,
#  'stamped': 936,
#  'material': 937,
#  'london': 938,
#  'banking': 939,
#  'job': 940,
#  'start': 941,
#  'large': 942,
#  'spike': 943,
#  'searches': 944,
#  'passport': 945,
#  'applications': 946,
#  'broke': 947,
#  'backs': 948,
#  'remain': 949,
#  '94': 950,
#  'night': 951,
#  'residents': 952,
#  'guilty': 953,
#  'insulting': 954,
#  'recep': 955,
#  'tayyip': 956,
#  'depicting': 957,
#  'gollum': 958,
#  'character': 959,
#  'lord': 960,
#  'rings': 961,
#  'antalya': 962,
#  'province': 963,
#  'rifat': 964,
#  'cetin': 965,
#  'jail': 966,
#  'sentence': 967,
#  'stripped': 968,
#  'parental': 969,
#  'custody': 970,
#  'today': 971,
#  'decides': 972,
#  'whether': 973,
#  'e': 974,
#  'cigarettes': 975,
#  'public': 976,
#  'warn': 977,
#  'ban': 978,
#  'using': 979,
#  'places': 980,
#  'damaging': 981,
#  'may': 982,
#  'put': 983,
#  'smokers': 984,
#  'quit': 985,
#  'rosanna': 986,
#  'connor': 987,
#  'health': 988,
#  'england': 989,
#  'china': 990,
#  'harvesting': 991,
#  'organs': 992,
#  'prisoners': 993,
#  'opens': 994,
#  'fire': 995,
#  'cinema': 996,
#  'complex': 997,
#  'several': 998,
#  'wounded': 999,
#  ...}

# %%
len(vocab_to_int)
# Out:
# 31791

# %%
# Special tokens that will be added to our vocab
codes = ["<UNK>","<PAD>"]   

# Add codes to vocab
for code in codes:
    vocab_to_int[code] = len(vocab_to_int)

# Dictionary to convert integers to words
int_to_vocab = {}
for word, value in vocab_to_int.items():
    int_to_vocab[value] = word

usage_ratio = round(len(vocab_to_int) / len(word_counts),4)*100

print("Total Number of Unique Words:", len(word_counts))
print("Number of Words we will use:", len(vocab_to_int))
print("Percent of Words we will use: {}%".format(usage_ratio))
# Out:
# Total Number of Unique Words: 36311
# Number of Words we will use: 31793
# Percent of Words we will use: 87.56%

# %% [markdown]
# ## For the words which are common within headlines but are absent in Glove corpus, we will have to randomly initialize them. Over the training, those values will be finetuned along with those of Glove vectors.

# %%
# Need to use 300 for embedding dimensions to match GloVe's vectors.
embedding_dim = 300

nb_words = len(vocab_to_int)
# Create matrix with default values of zero
word_embedding_matrix = np.zeros((nb_words+1, embedding_dim))
for word, i in vocab_to_int.items():
    if word in embeddings_index:
        word_embedding_matrix[i] = embeddings_index[word]
    else:
        # If word not in GloVe, create a random embedding for it
        new_embedding = np.array(np.random.uniform(-1.0, 1.0, embedding_dim))
        embeddings_index[word] = new_embedding
        word_embedding_matrix[i] = new_embedding

# Check if value matches len(vocab_to_int)
print(len(word_embedding_matrix))
# Out:
# (31794, 300)
# 31794

# %%
word_embedding_matrix.shape
# Out:
# (31794, 300)

# %% [markdown]
# ## Convert the word sequences to equivalent integer sequences so that it can be used as input to the model

# %%
# Change the text from words to integers
# If word is not in vocab, replace it with <UNK> (unknown)
word_count = 0
unk_count = 0

headlines_sequence = []

for daily_headline in clean_headlines:
    daily_headlines_seq = []
    for headline in daily_headline:
        headline_seq = []
        for word in headline.split():
            word_count += 1
            if word in vocab_to_int:
                headline_seq.append(vocab_to_int[word])
            else:
                headline_seq.append(vocab_to_int["<UNK>"])
                unk_count += 1
        daily_headlines_seq.append(headline_seq)
    headlines_sequence.append(daily_headlines_seq)

unk_percent = round(unk_count/word_count,4)*100

print("Total number of words in headlines:", word_count)
print("Total number of UNKs in headlines:", unk_count)
print("Percent of words that are UNK: {}%".format(unk_percent))

# %%
headlines_sequence[:1]

# %% [markdown]
# ## Ensure that the variations in the number of news headlines each day and length of each headlines are handled by taking an average number of headlines each day and average length per headline

# %%
# Find the length of headlines
lengths = []
for headlines in headlines_sequence:
    for headline in headlines:
        lengths.append(len(headline))

# Create a dataframe so that the values can be inspected
lengths = pd.DataFrame(lengths, columns=['counts'])

# %%
lengths.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-5666782c9acd> in <module>
# ----> 1 lengths.describe()
#
# NameError: name 'lengths' is not defined

# %% [markdown]
# ## Limit the length of a day's news to 200 words, and the length of any headline to 16 words. These values are chosen to not have an excessively long training time and balance the number of headlines used and the number of words from each headline.

# %%
max_headline_length = 16
max_daily_length = 200
pad_headlines = []

# For each date in all the dates available
for headlines in headlines_sequence:
    pad_daily_headlines = []
    # for each headline for each date
    for headline in headlines:
        # Add headline if it is less than max length
        if len(headline) <= max_headline_length:
            for word in headline:
                pad_daily_headlines.append(word)
        # Limit headline if it is more than max length  
        else:
            headline = headline[:max_headline_length]
            for word in headline:
                pad_daily_headlines.append(word)
    
    # Pad daily_headlines if they are less than max length
    if len(pad_daily_headlines) < max_daily_length:
        for i in range(max_daily_length-len(pad_daily_headlines)):
            pad = vocab_to_int["<PAD>"]
            pad_daily_headlines.append(pad)
    # Limit daily_headlines if they are more than max length
    else:
        pad_daily_headlines = pad_daily_headlines[:max_daily_length]
    pad_headlines.append(pad_daily_headlines)

# %% [markdown]
# ## Split data into training and testing sets.
# ## Validating data will be created during training.

# %%
x_train, x_test, y_train, y_test = train_test_split(pad_headlines, norm_price, test_size = 0.15, random_state = 2)

x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
# Check the lengths
print(len(x_train))
print(len(x_test))
# Out:
# 1689
# 299

# %% [markdown]
# # Model Building

# %% [markdown]
# ## The CNN-RNN architecture
# ![cnn-rnn](resources/cnn-1d-rnn.jpg)

# %% [markdown]
# ## 1. Define the hyperparameters

# %%
filter_length = 5
dropout = 0.5
learning_rate = 0.001
weights = initializers.TruncatedNormal(mean=0.0, stddev=0.1, seed=2)
nb_filter = 16
rnn_output_size = 128
hidden_dims = 128

# %% [markdown]
# ## 2. Create the model

# %%
def build_model():
    
    model = Sequential()
    
    # Layer 1 - Embedding
    model.add(Embedding(nb_words, 
                         embedding_dim,
                         weights=[word_embedding_matrix], 
                         input_length=max_daily_length))
    model.add(Dropout(dropout))
    
    # Layer 2 - Convolution 1 with dropout
    model.add(Convolution1D(filters = nb_filter, 
                             kernel_size = filter_length, 
                             padding = 'same',
                             activation = 'relu'))
    model.add(Dropout(dropout))    

    # Layer 3 - Convolution 2 with Dropout 
    model.add(Convolution1D(filters = nb_filter, 
                                 kernel_size = filter_length, 
                                 padding = 'same',
                                 activation = 'relu'))
    model.add(Dropout(dropout))    

    # Layer 4 - RNN with dropout
    model.add(LSTM(rnn_output_size, 
                    activation=None,
                    kernel_initializer=weights,
                    dropout = dropout))    

    # Layer 5 - Dense FFN with Dropout
    model.add(Dense(hidden_dims, kernel_initializer=weights))
    model.add(Dropout(dropout))
    
    model.add(Dense(1, 
                    kernel_initializer = weights,
                    name='output'))

    model.compile(loss='mean_squared_error',
                  optimizer=Adam(lr=learning_rate,clipvalue=1.0))
    return model

# %% [markdown]
# ## 3. Fit the model

# %%
model = build_model()
print()
save_best_weights = 'best_weights.h5'

callbacks = [ModelCheckpoint(save_best_weights, monitor='val_loss', save_best_only=True),
            EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto'),
            ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=3)]

history = model.fit([x_train],
                    y_train,
                    batch_size=128,
                    epochs=100,
                    validation_split=0.15,
                    verbose=True,
                    shuffle=True,
                    callbacks = callbacks)
print(model.summary())
# Out:
# WARNING:tensorflow:From /Users/alethea/miniconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/alethea/miniconda3/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /Users/alethea/miniconda3/lib/python3.7/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#
# Train on 1435 samples, validate on 254 samples
# WARNING:tensorflow:From /Users/alethea/miniconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 1435/1435 [==============================] - 19s 13ms/sample - loss: 0.0810 - val_loss: 0.0827
# Epoch 2/100
# 1435/1435 [==============================] - 17s 12ms/sample - loss: 0.0329 - val_loss: 0.0396
# Epoch 3/100
# 1435/1435 [==============================] - 16s 11ms/sample - loss: 0.0203 - val_loss: 0.0239
# Epoch 4/100
# 1435/1435 [==============================] - 14s 10ms/sample - loss: 0.0151 - val_loss: 0.0152
# Epoch 5/100
# 1435/1435 [==============================] - 14s 10ms/sample - loss: 0.0133 - val_loss: 0.0103
# Epoch 6/100
# 1435/1435 [==============================] - 14s 10ms/sample - loss: 0.0116 - val_loss: 0.0088
# Epoch 7/100
# 1435/1435 [==============================] - 16s 11ms/sample - loss: 0.0116 - val_loss: 0.0079
# Epoch 8/100
# 1435/1435 [==============================] - 14s 10ms/sample - loss: 0.0103 - val_loss: 0.0073
# Epoch 9/100
# 1435/1435 [==============================] - 14s 10ms/sample - loss: 0.0104 - val_loss: 0.0074
# Epoch 10/100
# 1435/1435 [==============================] - 14s 10ms/sample - loss: 0.0101 - val_loss: 0.0071
# Epoch 11/100
# 1435/1435 [==============================] - 14s 10ms/sample - loss: 0.0099 - val_loss: 0.0071
# Epoch 12/100
# 1435/1435 [==============================] - 14s 10ms/sample - loss: 0.0097 - val_loss: 0.0076
# Epoch 13/100
# 1408/1435 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1435/1435 [==============================] - 14s 10ms/sample - loss: 0.0094 - val_loss: 0.0072
# Epoch 14/100
# 1435/1435 [==============================] - 14s 10ms/sample - loss: 0.0093 - val_loss: 0.0071
# Epoch 15/100
# 1435/1435 [==============================] - 14s 10ms/sample - loss: 0.0094 - val_loss: 0.0072
# Epoch 00015: early stopping
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 200, 300)          9537900
# _________________________________________________________________
# dropout (Dropout)            (None, 200, 300)          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 200, 16)           24016
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 200, 16)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 200, 16)           1296
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 200, 16)           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 128)               74240
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 1)                 129
# =================================================================
# Total params: 9,654,093
# Trainable params: 9,654,093
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## 4. Predict using the model

# %%
predictions = model.predict([x_test], verbose = True)
# Out:
# 299/299 [==============================] - 1s 5ms/sample

# %%
# Compare testing loss to training and validating loss
mse(y_test, predictions)
# Out:
# 0.0069998669539292745

# %%
# Revert prediction back to actual scale
def unnormalize(price):
    '''Revert values to their unnormalized amounts'''
    price = price*(max_price-min_price)+min_price
    return(price)

# %%
# Store back-scaled predictions
unnorm_predictions = []
for pred in predictions:
    unnorm_predictions.append(unnormalize(pred))

# Store back-scaled actuals
unnorm_y_test = []
for y in y_test:
    unnorm_y_test.append(unnormalize(y))

# %%
# Calculate the median absolute error for the predictions
mae(unnorm_y_test, unnorm_predictions)
# Out:
# 75.79931665624827

# %%
pd.Series(unnorm_y_test).describe()
# Out:
# count    299.000000
# mean       7.094101
# std      139.532324
# min     -673.139648
# 25%      -54.689941
# 50%       10.759766
# 75%       87.465332
# max      541.050782
# dtype: float64

# %% [markdown]
# ## Make Your Own Predictions

# %% [markdown]
# Below is the code necessary to make your own predictions. I found that the predictions are most accurate when there is no padding included in the input data. In the create_news variable, I have some default news that you can use, which is from April 30th, 2017. Just change the text to whatever you want, then see the impact your new headline will have.

# %%
def news_to_int(news):
    '''Convert your created news into integers'''
    ints = []
    for word in news.split():
        if word in vocab_to_int:
            ints.append(vocab_to_int[word])
        else:
            ints.append(vocab_to_int['<UNK>'])
    return ints

# %%
def padding_news(news):
    '''Adjusts the length of your created news to fit the model's input values.'''
    padded_news = news
    if len(padded_news) < max_daily_length:
        for i in range(max_daily_length-len(padded_news)):
            padded_news.append(vocab_to_int["<PAD>"])
    elif len(padded_news) > max_daily_length:
        padded_news = padded_news[:max_daily_length]
    return padded_news

# %%
# Default news that you can use

create_news =  "Woman says note from Chinese 'prisoner' was hidden in new purse. \
               21,000 AT&T workers poised for Monday strike \
               housands march against Trump climate policies in D.C., across USA \
               Kentucky judge won't hear gay adoptions because it's not in the child's \"best interest\" \
               Multiple victims shot in UTC area apartment complex \
               Drones Lead Police to Illegal Dumping in Riverside County | NBC Southern California \
               An 86-year-old Californian woman has died trying to fight a man who was allegedly sexually assaulting her 61-year-old friend. \
               Fyre Festival Named in $5Million+ Lawsuit after Stranding Festival-Goers on Island with Little Food, No Security. \
               The \"Greatest Show on Earth\" folds its tent for good \
               U.S.-led fight on ISIS have killed 352 civilians: Pentagon \
               Woman offers undercover officer sex for $25 and some Chicken McNuggets \
               Ohio bridge refuses to fall down after three implosion attempts \
               Jersey Shore MIT grad dies in prank falling from library dome \
               New York graffiti artists claim McDonald's stole work for latest burger campaign \
               SpaceX to launch secretive satellite for U.S. intelligence agency \
               Severe Storms Leave a Trail of Death and Destruction Through the U.S. \
               Hamas thanks N. Korea for its support against ‘Israeli occupation’ \
               Baker Police officer arrested for allegedly covering up details in shots fired investigation \
               Miami doctor’s call to broker during baby’s delivery leads to $33.8 million judgment \
               Minnesota man gets 15 years for shooting 5 Black Lives Matter protesters \
               South Australian woman facing possible 25 years in Colombian prison for drug trafficking \
               The Latest: Deal reached on funding government through Sept. \
               Russia flaunts Arctic expansion with new military bases"

clean_news = clean_text(create_news)

int_news = news_to_int(clean_news)

pad_news = padding_news(int_news)

pad_news = np.array(pad_news).reshape((1,-1))

pred = model.predict([pad_news])

price_change = unnormalize(pred)

print("The Dow should open: {} from the previous open.".format(np.round(price_change[0][0],2)))
# Out:
# The Dow should open: -22.260000228881836 from the previous open.
