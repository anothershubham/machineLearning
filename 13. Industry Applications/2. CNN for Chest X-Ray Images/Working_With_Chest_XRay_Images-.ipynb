# %% [markdown]
# # Analysis of Chest X-Ray images

# %% [markdown]
# Neural networks have revolutionised image processing in several different domains. Among these is the field of medical imaging. In the following notebook, we will get some hands-on experience in working with Chest X-Ray (CXR) images.
#
# The objective of this exercise is to identify images where an "effusion" is present. This is a classification problem, where we will be dealing with two classes - 'effusion' and 'nofinding'. Here, the latter represents a "normal" X-ray image.
#
# This same methodology can be used to spot various other illnesses that can be detected via a chest x-ray. For the scope of this demonstration, we will specifically deal with "effusion".

# %% [markdown]
# ## 1. Data Pre-processing

# %% [markdown]
# Our data is in the form of grayscale (black and white) images of chest x-rays. To perform our classification task effectively, we need to perform some pre-processing of the data.
#
# First, we load all the relevant libraries.

# %%
from skimage import io
import os
import glob
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# Point a variable to the path where the data resides. Note that to use the code below you will need to move the folders effusion/ and nofinding/ into one common folder. You can do something like this:
#
# ```
# mkdir CXR_Data
# move effusion CXR_Data
# move nofinding CXR_Data
# ```

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# %cd gdrive/MyDrive/CNN\ X-Ray\ CXR
# Out:
# /content/gdrive/MyDrive/CNN X-Ray CXR

# %%
# !ls
# Out:
# 'CXR data'	       models	    'resnet (1).py'
#  CXR_data_UpGrad.zip   __pycache__   resnet.py

# %%
# !unzip "CXR_data_UpGrad.zip" -d "/content/gdrive/MyDrive/CNN X-Ray CXR/"
# Out:
# Archive:  CXR_data_UpGrad.zip
#    creating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006592_000.png
#    creating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/
#    creating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006592_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006596_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006596_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006600_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006600_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006626_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006626_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006649_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006649_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006663_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006663_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006667_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006667_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006705_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006705_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006708_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006708_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006713_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006713_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006741_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006741_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006744_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006744_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006754_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006754_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006819_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006819_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006848_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006848_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006857_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006857_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006862_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006862_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006864_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006864_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006873_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006873_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006889_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006889_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006944_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006944_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006946_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006946_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006953_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006953_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00006973_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00006973_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007002_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007002_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007012_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007012_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007049_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007049_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007055_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007055_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007076_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007076_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007121_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007121_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007151_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007151_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007156_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007156_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007218_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007218_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007254_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007254_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007300_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007300_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007308_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007308_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007355_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007355_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007421_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007421_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007485_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007485_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007520_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007520_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007522_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007522_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007545_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007545_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007564_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007564_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007576_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007576_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007622_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007622_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007626_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007626_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007629_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007629_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007633_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007633_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007652_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007652_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007659_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007659_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007679_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007679_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007682_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007682_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007718_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007718_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007720_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007720_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007744_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007744_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007768_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007768_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007772_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007772_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007804_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007804_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007808_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007808_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007830_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007830_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007833_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007833_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007842_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007842_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007859_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007859_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007862_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007862_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007882_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007882_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007908_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007908_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00007933_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00007933_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008037_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008037_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008038_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008038_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008042_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008042_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008087_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008087_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008112_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008112_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008187_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008187_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008195_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008195_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008214_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008214_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008219_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008219_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008324_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008324_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008352_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008352_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008372_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008372_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008434_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008434_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008463_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008463_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008471_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008471_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008509_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008509_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008510_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008510_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008577_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008577_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008585_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008585_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008622_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008622_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008637_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008637_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008638_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008638_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008774_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008774_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008777_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008777_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008814_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008814_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008827_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008827_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008844_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008844_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008868_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008868_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008905_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008905_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008910_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008910_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00008974_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00008974_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00009047_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00009047_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00009073_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00009073_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00009106_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00009106_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00009116_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00009116_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00009141_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00009141_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00009144_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00009144_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00009163_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00009163_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00009171_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00009171_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/effusion/00009211_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/effusion/._00009211_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/._effusion
#    creating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006589_000.png
#    creating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006589_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006590_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006590_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006591_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006591_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006593_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006593_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006594_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006594_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006595_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006595_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006597_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006597_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006598_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006598_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006599_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006599_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006602_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006602_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006604_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006604_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006606_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006606_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006607_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006607_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006608_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006608_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006609_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006609_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006610_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006610_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006611_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006611_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006613_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006613_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006614_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006614_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006615_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006615_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006616_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006616_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006617_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006617_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006618_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006618_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006619_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006619_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006620_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006620_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006621_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006621_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006622_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006622_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006623_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006623_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006625_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006625_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006627_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006627_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006628_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006628_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006631_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006631_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006633_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006633_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006634_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006634_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006635_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006635_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006636_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006636_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006637_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006637_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006638_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006638_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/nofinding/00006640_000.png
#   inflating: /content/gdrive/MyDrive/CNN X-Ray CXR/__MACOSX/nofinding/._00006640_000.png

# %%
DATASET_PATH = './CXR data/'

# There are two classes of images that we will deal with
disease_cls = ['effusion', 'nofinding']

# %% [markdown]
# Next, we read the "effusion" and "nofinding" images.

# %%
effusion_path = os.path.join(DATASET_PATH, disease_cls[0], '*')
effusion = glob.glob(effusion_path)
effusion = io.imread(effusion[0])

normal_path = os.path.join(DATASET_PATH, disease_cls[1], '*')
normal = glob.glob(normal_path)
normal = io.imread(normal[0])

f, axes = plt.subplots(1, 2, sharey=True)
f.set_figwidth(10)
    
axes[0].imshow(effusion, cmap='gray')
axes[1].imshow(normal, cmap='gray')

# %%
effusion.shape
# Out:
# (1024, 1024)

# %%
normal.shape
# Out:
# (1024, 1024)

# %% [markdown]
# ### Data Augmentation ###
#
# Now that we have read the images, the next step is data augmentation. We use the concept of a "data generator" that you learnt in the last section.

# %%
from skimage.transform import rescale
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=10,
    width_shift_range=0,
    height_shift_range=0,
    vertical_flip=False,)

def preprocess_img(img, mode):
    img = (img - img.min())/(img.max() - img.min())
    img = rescale(img, 0.25, multichannel=True, mode='constant')
    
    if mode == 'train':
        if np.random.randn() > 0:
            img = datagen.random_transform(img)
    return img

# %% [markdown]
# ## 2. Model building

# %% [markdown]
# We will be using a Resnet in this (you learnt about Resnets previously).
#
# For this to work, the script that defines the resnet model (resnet.py) should reside in the same folder as this notebook

# %%
from google.colab import files
src = list(files.upload().values())[0]
# open('resnet.py','wb').write(src)
# import mylib
# Out:
#      <input type="file" id="files-eeda85ed-29c5-4c30-bbe0-b9f786bfaa4f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eeda85ed-29c5-4c30-bbe0-b9f786bfaa4f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-30d5a518c14f> in <module>()
#       1 from google.colab import files
# ----> 2 src = list(files.upload().values())[0]
#       3 # open('resnet.py','wb').write(src)
#       4 # import mylib
#
# IndexError: list index out of range

# %%
import resnet

img_channels = 1
img_rows = 256
img_cols = 256

nb_classes = 2

# %%
import numpy as np
import tensorflow as tf

class AugmentedDataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, mode='train', ablation=None, disease_cls = ['nofinding', 'effusion'], 
                 batch_size=32, dim=(256, 256), n_channels=1, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.labels = {}
        self.list_IDs = []
        self.mode = mode
        
        for i, cls in enumerate(disease_cls):
            paths = glob.glob(os.path.join(DATASET_PATH, cls, '*'))
            brk_point = int(len(paths)*0.8)
            if self.mode == 'train':
                paths = paths[:brk_point]
            else:
                paths = paths[brk_point:]
            if ablation is not None:
                paths = paths[:int(len(paths)*ablation/100)]
            self.list_IDs += paths
            self.labels.update({p:i for p in paths})
        
            
        self.n_channels = n_channels
        self.n_classes = len(disease_cls)
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'

        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        list_IDs_temp = [self.list_IDs[k] for k in indexes]

        X, y = self.__data_generation(list_IDs_temp)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.empty((self.batch_size, *self.dim, self.n_channels))
        y = np.empty((self.batch_size), dtype=int)
        
        delete_rows = []

        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            img = io.imread(ID)
            img = img[:, :, np.newaxis]
            if img.shape == (1024, 1024,1):
                img = preprocess_img(img, self.mode)
                X[i,] = img
                y[i] = self.labels[ID]
            else:
                delete_rows.append(i)
                continue
                
        X = np.delete(X, delete_rows, axis=0)
        y = np.delete(y, delete_rows, axis=0)
        
        return X, tf.keras.utils.to_categorical(y, num_classes=self.n_classes)

# %% [markdown]
# ## 3. Ablation Run

# %% [markdown]
# In the previous notebook, you learnt about Ablation. Briefly, an ablation run is when you systematically modify certain parts of the input, in order to observe the equivalent change in the input.
#
# For the following section, we'll be using the Data Generator concept that you previously worked on.

# %%
model = resnet.ResnetBuilder.build_resnet_18((img_channels, img_rows, img_cols), nb_classes)
model.compile(loss='categorical_crossentropy',optimizer='SGD',
              metrics=['accuracy'])
training_generator = AugmentedDataGenerator('train', ablation=5)
validation_generator = AugmentedDataGenerator('val', ablation=5)

model.fit(training_generator, epochs=1, validation_data=validation_generator)
# Out:
# 1/1 [==============================] - 36s 36s/step - loss: 1.3814 - accuracy: 1.0000

# %%
model = resnet.ResnetBuilder.build_resnet_18((img_channels, img_rows, img_cols), nb_classes)
model.compile(loss='categorical_crossentropy',optimizer='SGD',
              metrics=['accuracy'])

training_generator = AugmentedDataGenerator('train', ablation=5)
validation_generator = AugmentedDataGenerator('val', ablation=5)

model.fit(training_generator, epochs=5, validation_data=None)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 6s 6s/step - loss: 1.5764 - accuracy: 0.6667
# Epoch 2/5
# 1/1 [==============================] - 3s 3s/step - loss: 1.4046 - accuracy: 0.9355
# Epoch 3/5
# 1/1 [==============================] - 3s 3s/step - loss: 1.3689 - accuracy: 0.8710
# Epoch 4/5
# 1/1 [==============================] - 3s 3s/step - loss: 1.3149 - accuracy: 0.9000
# Epoch 5/5
# 1/1 [==============================] - 3s 3s/step - loss: 1.2861 - accuracy: 0.9032

# %%
from sklearn.metrics import roc_auc_score
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import *

class roc_callback(Callback):
    
    def on_train_begin(self, logs={}):
        logs['val_auc'] = 0

    def on_epoch_end(self, epoch, logs={}):
        y_p = []
        y_v = []
        for i in range(len(validation_generator)):
            x_val, y_val = validation_generator[i]
            y_pred = self.model.predict(x_val)
            y_p.append(y_pred)
            y_v.append(y_val)
        y_p = np.concatenate(y_p)
        y_v = np.concatenate(y_v)
        roc_auc = roc_auc_score(y_v, y_p)
        print ('\nVal AUC for epoch{}: {}'.format(epoch, roc_auc))
        logs['val_auc'] = roc_auc

# %%
model = resnet.ResnetBuilder.build_resnet_18((img_channels, img_rows, img_cols), nb_classes)
model.compile(loss='categorical_crossentropy',optimizer='SGD',
              metrics=['accuracy'])

training_generator = AugmentedDataGenerator('train', ablation=20)
validation_generator = AugmentedDataGenerator('val', ablation=20)

auc_logger = roc_callback()

model.fit(training_generator, epochs=5, validation_data=validation_generator, callbacks=[auc_logger])
# Out:
# Epoch 1/5
# 5/5 [==============================] - 59s 12s/step - loss: 1.6975 - accuracy: 0.5962 - val_loss: 2.7524 - val_accuracy: 0.8750
#
# Val AUC for epoch0: 0.5178571428571428
# Epoch 2/5
# 5/5 [==============================] - 19s 4s/step - loss: 1.2943 - accuracy: 0.9091 - val_loss: 2.5102 - val_accuracy: 0.8750
#
# Val AUC for epoch1: 0.6408045977011494
# Epoch 3/5
# 5/5 [==============================] - 16s 3s/step - loss: 1.3069 - accuracy: 0.8961 - val_loss: 1.7585 - val_accuracy: 0.9062
#
# Val AUC for epoch2: 0.5267857142857143
# Epoch 4/5
# 5/5 [==============================] - 16s 3s/step - loss: 1.2978 - accuracy: 0.8903 - val_loss: 1.7904 - val_accuracy: 0.8750
#
# Val AUC for epoch3: 0.5357142857142857
# Epoch 5/5
# 5/5 [==============================] - 15s 3s/step - loss: 1.3017 - accuracy: 0.8903 - val_loss: 1.6043 - val_accuracy: 0.8750
#
# Val AUC for epoch4: 0.5089285714285714

# %%
from functools import partial
import tensorflow.keras.backend as K
from itertools import product

def w_categorical_crossentropy(y_true, y_pred, weights):
    nb_cl = len(weights)
    final_mask = K.zeros_like(y_pred[:, 0])
    y_pred_max = K.max(y_pred, axis=1)
    y_pred_max = K.reshape(y_pred_max, (K.shape(y_pred)[0], 1))
    y_pred_max_mat = K.cast(K.equal(y_pred, y_pred_max), K.floatx())
    for c_p, c_t in product(range(nb_cl), range(nb_cl)):
        final_mask += (weights[c_t, c_p] * y_pred_max_mat[:, c_p] * y_true[:, c_t])
    cross_ent = K.categorical_crossentropy(y_true, y_pred, from_logits=False)
    return cross_ent * final_mask

bin_weights = np.ones((2,2))
bin_weights[0, 1] = 5
bin_weights[1, 0] = 5
ncce = partial(w_categorical_crossentropy, weights=bin_weights)
ncce.__name__ ='w_categorical_crossentropy'

# %%
model = resnet.ResnetBuilder.build_resnet_18((img_channels, img_rows, img_cols), nb_classes)
model.compile(loss=ncce, optimizer='SGD',
              metrics=['accuracy'])

training_generator = AugmentedDataGenerator('train', ablation=5)
validation_generator = AugmentedDataGenerator('val', ablation=5)

model.fit(training_generator, epochs=1, validation_data=None)
# Out:
# 1/1 [==============================] - 5s 5s/step - loss: 2.0926 - accuracy: 0.8438

# %% [markdown]
# ## 4. Final Run

# %% [markdown]
# After deeply examining our data and building some preliminary models, we are finally ready to build a model that will perform our prediction task.

# %%
class DecayLR(tf.keras.callbacks.Callback):
    def __init__(self, base_lr=0.01, decay_epoch=1):
        super(DecayLR, self).__init__()
        self.base_lr = base_lr
        self.decay_epoch = decay_epoch 
        self.lr_history = []
        
    def on_train_begin(self, logs={}):
        K.set_value(self.model.optimizer.lr, self.base_lr)

    def on_epoch_end(self, epoch, logs={}):
        new_lr = self.base_lr * (0.5 ** (epoch // self.decay_epoch))
        self.lr_history.append(K.get_value(self.model.optimizer.lr))
        K.set_value(self.model.optimizer.lr, new_lr)

# %%
model = resnet.ResnetBuilder.build_resnet_18((img_channels, img_rows, img_cols), nb_classes)
sgd = optimizers.SGD(lr=0.005)

bin_weights = np.ones((2,2))
bin_weights[1, 1] = 10
bin_weights[1, 0] = 10
ncce = partial(w_categorical_crossentropy, weights=bin_weights)
ncce.__name__ ='w_categorical_crossentropy'

model.compile(loss=ncce,optimizer= sgd,
              metrics=['accuracy'])
training_generator = AugmentedDataGenerator('train', ablation=50)
validation_generator = AugmentedDataGenerator('val', ablation=50)

auc_logger = roc_callback()
filepath = 'models/best_model.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor='val_auc', verbose=1, save_best_only=True, mode='max')

decay = DecayLR()

model.fit(training_generator, epochs=10, validation_data=validation_generator, callbacks=[auc_logger, decay, checkpoint])
# Out:
# Epoch 1/10
# 13/13 [==============================] - 121s 9s/step - loss: 2.2807 - accuracy: 0.4684 - val_loss: 2.8680 - val_accuracy: 0.0938
#
# Val AUC for epoch0: 0.5287356321839081
#
# Epoch 00001: val_auc improved from -inf to 0.52874, saving model to models/best_model.hdf5
# Epoch 2/10
# 13/13 [==============================] - 44s 3s/step - loss: 2.2599 - accuracy: 0.5455 - val_loss: 5.3664 - val_accuracy: 0.0938
#
# Val AUC for epoch1: 0.45581395348837206
#
# Epoch 00002: val_auc did not improve from 0.52874
# Epoch 3/10
# 13/13 [==============================] - 41s 3s/step - loss: 2.1775 - accuracy: 0.4975 - val_loss: 3.4993 - val_accuracy: 0.1042
#
# Val AUC for epoch2: 0.5229946524064171
#
# Epoch 00003: val_auc did not improve from 0.52874
# Epoch 4/10
# 13/13 [==============================] - 40s 3s/step - loss: 2.1793 - accuracy: 0.5544 - val_loss: 2.8085 - val_accuracy: 0.1146
#
# Val AUC for epoch3: 0.5679144385026738
#
# Epoch 00004: val_auc improved from 0.52874 to 0.56791, saving model to models/best_model.hdf5
# Epoch 5/10
# 13/13 [==============================] - 40s 3s/step - loss: 2.1152 - accuracy: 0.6354 - val_loss: 2.6025 - val_accuracy: 0.1146
#
# Val AUC for epoch4: 0.49534883720930234
#
# Epoch 00005: val_auc did not improve from 0.56791
# Epoch 6/10
# 13/13 [==============================] - 40s 3s/step - loss: 2.1097 - accuracy: 0.6826 - val_loss: 2.5204 - val_accuracy: 0.1042
#
# Val AUC for epoch5: 0.5389527458492975
#
# Epoch 00006: val_auc did not improve from 0.56791
# Epoch 7/10
# 13/13 [==============================] - 40s 3s/step - loss: 2.1323 - accuracy: 0.6701 - val_loss: 2.4627 - val_accuracy: 0.0938
#
# Val AUC for epoch6: 0.3964686998394864
#
# Epoch 00007: val_auc did not improve from 0.56791
# Epoch 8/10
# 13/13 [==============================] - 40s 3s/step - loss: 2.1137 - accuracy: 0.6599 - val_loss: 2.4023 - val_accuracy: 0.0729
#
# Val AUC for epoch7: 0.6149732620320856
#
# Epoch 00008: val_auc improved from 0.56791 to 0.61497, saving model to models/best_model.hdf5
# Epoch 9/10
# 13/13 [==============================] - 40s 3s/step - loss: 2.0976 - accuracy: 0.6405 - val_loss: 2.4346 - val_accuracy: 0.1146
#
# Val AUC for epoch8: 0.6551724137931034
#
# Epoch 00009: val_auc improved from 0.61497 to 0.65517, saving model to models/best_model.hdf5
# Epoch 10/10
# 13/13 [==============================] - 39s 3s/step - loss: 2.1234 - accuracy: 0.6532 - val_loss: 2.3625 - val_accuracy: 0.0938
#
# Val AUC for epoch9: 0.6255813953488372
#
# Epoch 00010: val_auc did not improve from 0.65517

# %% [markdown]
# ## 5. Making a Prediction

# %%
val_model = resnet.ResnetBuilder.build_resnet_18((img_channels, img_rows, img_cols), nb_classes)
val_model.load_weights('models/best_model.hdf5')

# %%
effusion_path = os.path.join(DATASET_PATH, disease_cls[0], '*')
effusion = glob.glob(effusion_path)
effusion = io.imread(effusion[-8])
plt.imshow(effusion,cmap='gray')

# %%
img = preprocess_img(effusion[:, :, np.newaxis], 'validation')
val_model.predict(img[np.newaxis,:])
# Out:
# array([[0.28434792, 0.71565205]], dtype=float32)
